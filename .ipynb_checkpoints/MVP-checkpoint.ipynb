# %% [markdown]
# # MLS Player Performance Review

# %%
Image(url='https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/MLS_crest_logo_RGB_gradient.svg/440px-MLS_crest_logo_RGB_gradient.svg.png')
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/76/MLS_crest_logo_RGB_gradient.svg/440px-MLS_crest_logo_RGB_gradient.svg.png"/>

# %% [markdown]
# ## Overview
#
# Major League Soccer (MLS) has been keeping data on its players for years and would like to utilize that data to evaluate player performance and its relationship to player salary. By anazlying this data , I hope to create a predictive model that can highlight this link and the particular aspects of player performance that are most tied to salary.

# %% [markdown]
# ## Business Problem
#
# MLS has growing rapidly and gaining in popularity, increasing their number of teams from just 13 in 2007 to 29 today. Likewise, the average team revenue increased from  37 million USD in 2008 to 582 million USD in 2022. This also saw an increase in player salary over the years. In order to figure out what a player's salary should be, I analyzed a player's statistics by year in order to come up with recommendations to further bolster future analysis.

# %% [markdown]
# ## Data Understanding
# The statistics datasets in this analysis come from Mlssoccer.com, provided by (Kaggle Dataset) via webscraping before the website changed how it displayed information. The salary datasets come directly from the MLSPA(Major League Soccer Players Association) on mlsplayers.org. I analyzed XXXX players from the combined dataframe of these sources ranging from 2007-2022.
#
# The statsistics datasets were csv files containing information about a field player's and goalkeeper's performance on field during a season. The field player's dataset includes information such as goals, assists, games played, total minutes played, and more. the goalkeeper's dataset included some similar information such as games played and total minutes played, but also contained unique statistics like saves, goals conceded, and wins, losses, and ties.

# %% [markdown]
# ## Data Preparation
#
# MLS wants to continue to expand and entice players the likes of Lionel Messi into the league. In order to understand the current salaries of players in the league, I combined the statistics and salary datasets.
#
# I trained a Linear Regression Model, Random Forest Regression Model, and KNearestNeighbors Regression Model. I utilized a Pipeline and GridSearch for each of these to crossvalidate scores and iterate over many different models. I added and modified several feature columns, including Penaly Kick Conversion Rates, whether a player made the Postseason, a one-hot encoded breakdown of player position, and more. My final dataframe contained XX features that were used by these models to more accurately predict Player salary. I used r2 score, MSE, RMSE, and MAE to help evaluate how well my models were performing, but ultimately looked at r2 score and RMSE as my most important metrics to measure how far off a model was predicting salary.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
from rapidfuzz import fuzz
import re
from unidecode import unidecode
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.datasets import make_blobs
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import r2_score, silhouette_score, mean_squared_error, mean_absolute_error 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from IPython.display import Image

# %% [markdown]
# ### Reading Data
# These datasets are directly inside the repository and are accessed using the below code.

# %%
# Loading csv files into dataframes
player_stats_df = pd.read_csv('./data/Player_stats/all_players.csv')
keeper_stats_df = pd.read_csv('./data/Player_stats/all_goalkeepers.csv')

# %% [markdown]
# ### Data Cleaning

# %%
# PKG/A needs to be changed as it is fractions in the form of strings.
keeper_stats_df.head()
# Out:
#            Player Club POS  GP  GS  MINS  SHTS   SV  GA   GAA PKG/A   W   L  \
# 0       Mark Dodd  DAL  GK  31  31  2776   235  160  45  1.45   5/5  17  14
# 1      Tony Meola  MET  GK  29  29  2610   188  142  38  1.31   3/4  14  15
# 2  Mark Dougherty  TB   GK  28  28  2520   186  123  47  1.68  9/10  17  11
# 3    Jorge Campos  LA   GK  24  24  2160   133  100  27  1.13   0/1  13   8
# 4  Garth Lagerwey  KC   GK  23  22  1959   133   83  38  1.73   2/2  12  10
#
#    T  ShO    W%   Sv%  Year Season
# 0  0    6  54.8  68.1  1996    reg
# 1  0    9  48.3  75.5  1996    reg
# 2  0    3  60.7  66.1  1996    reg
# 3  0    4  54.2  75.2  1996    reg
# 4  0    3  52.2  62.4  1996    reg

# %%
# Will be dropping Club, so no nulls to deal with in this dataframe
keeper_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  2006 non-null   object
#  1   Club    1324 non-null   object
#  2   POS     2006 non-null   object
#  3   GP      2006 non-null   int64
#  4   GS      2006 non-null   int64
#  5   MINS    2006 non-null   int64
#  6   SHTS    2006 non-null   int64
#  7   SV      2006 non-null   int64
#  8   GA      2006 non-null   int64
#  9   GAA     2006 non-null   float64
#  10  PKG/A   2006 non-null   object
#  11  W       2006 non-null   int64
#  12  L       2006 non-null   int64
#  13  T       2006 non-null   int64
#  14  ShO     2006 non-null   int64
#  15  W%      2006 non-null   float64
#  16  Sv%     2006 non-null   float64
#  17  Year    2006 non-null   int64
#  18  Season  2006 non-null   object
# dtypes: float64(3), int64(11), object(5)
# memory usage: 297.9+ KB

# %%
keeper_stats_df.describe()
# Out:
#                 GP           GS         MINS         SHTS           SV  \
# count  2006.000000  2006.000000  2006.000000  2006.000000  2006.000000
# mean      6.804586     6.677966   603.997009    33.926720    23.310568
# std      10.316232    10.292286   924.747438    52.330135    36.569597
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.000000     1.000000    90.000000     7.000000     4.000000
# 75%       9.000000     8.000000   770.250000    47.000000    31.000000
# max      34.000000    34.000000  3060.000000   249.000000   184.000000
#
#                 GA          GAA            W            L            T  \
# count  2006.000000  2006.000000  2006.000000  2006.000000  2006.000000
# mean      9.608175     0.888500     2.629611     2.626620     1.420738
# std      14.673335     0.992154     4.433369     4.090945     2.753633
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       2.000000     0.940000     0.000000     1.000000     0.000000
# 75%      13.750000     1.500000     3.000000     3.000000     1.000000
# max      64.000000     6.000000    22.000000    19.000000    18.000000
#
#                ShO           W%          Sv%         Year
# count  2006.000000  2006.000000  2006.000000  2006.000000
# mean      1.606680    18.861316    37.418096  2010.110668
# std       2.855163    24.494023    34.628706     7.284097
# min       0.000000     0.000000     0.000000  1996.000000
# 25%       0.000000     0.000000     0.000000  2004.000000
# 50%       0.000000     0.000000    52.700000  2011.000000
# 75%       2.000000    37.500000    68.900000  2016.750000
# max      16.000000   100.000000   100.000000  2020.000000

# %%
player_stats_df.head()
# Out:
#             Player Club POS  GP  GS  MINS   G   A  SHTS  SOG  ...  RdA  \
# 0     Roy Lassiter  TB    F  30  30  2580  27   4    76   49  ...    2
# 1   Raul Diaz Arce  DC    F  28  28  2351  23   2   100   49  ...    2
# 2  Eduardo Hurtado  LA    F  26  26  2323  21   7    87   56  ...    3
# 3            Preki  KC    M  32  32  2880  18  13   140   61  ...    4
# 4    Brian McBride  CLB   F  28  28  2307  17   3    79   44  ...    1
#
#   A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 0    0.14  20  39   70   2   0  64.47  1996     reg
# 1    0.08  32  26   35   6   1  49.00  1996     reg
# 2    0.27  48  26   25   5   0  64.37  1996     reg
# 3    0.41  26  44    7   3   0  43.57  1996     reg
# 4    0.12  21  46   10   0   0  55.70  1996     reg
#
# [5 rows x 28 columns]

# %%
#A lot of columns to sift through, but no nulls to deal with since we will be dropping club. 
player_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15767 entries, 0 to 15766
# Data columns (total 28 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   15767 non-null  object
#  1   Club     10274 non-null  object
#  2   POS      15767 non-null  object
#  3   GP       15767 non-null  int64
#  4   GS       15767 non-null  int64
#  5   MINS     15767 non-null  int64
#  6   G        15767 non-null  int64
#  7   A        15767 non-null  int64
#  8   SHTS     15767 non-null  int64
#  9   SOG      15767 non-null  int64
#  10  GWG      15767 non-null  int64
#  11  PKG/A    15767 non-null  object
#  12  HmG      15767 non-null  int64
#  13  RdG      15767 non-null  int64
#  14  G/90min  15767 non-null  float64
#  15  SC%      15767 non-null  float64
#  16  GWA      15767 non-null  int64
#  17  HmA      15767 non-null  int64
#  18  RdA      15767 non-null  int64
#  19  A/90min  15767 non-null  float64
#  20  FC       15767 non-null  int64
#  21  FS       15767 non-null  int64
#  22  OFF      15767 non-null  int64
#  23  YC       15767 non-null  int64
#  24  RC       15767 non-null  int64
#  25  SOG%     10697 non-null  float64
#  26  Year     15767 non-null  int64
#  27  Season   15767 non-null  object
# dtypes: float64(4), int64(19), object(5)
# memory usage: 3.4+ MB

# %% [markdown]
# I had to filter the statistics dataframe down to just the years 2007-2020 since that is the furthest back I was able to access
# salary data. Consequently it is also the year the Designated Player rule (commonly referred to as the "Beckham rule" ) was first implemented; it is credited as the most important catalyst that spurred the beginning of the rapid expansion of MLS.

# %%
#Creating a list of the years we want to use from the dataframes. Salary data is only accessible back to 2007.
years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
#Filtering dataframes to only show years in the years list
player_stats_df = player_stats_df[player_stats_df['Year'].isin(years)]
keeper_stats_df = keeper_stats_df[keeper_stats_df['Year'].isin(years)]

# %%
player_stats_df
# Out:
#                   Player Club  POS  GP  GS  MINS   G  A  SHTS  SOG  ...  RdA  \
# 3029      Luciano Emilio  DC     F  29  28  2410  20  1    79   47  ...    0
# 3030    Juan Pablo Angel  NY     F  24  24  2125  19  5    97   53  ...    2
# 3031     Taylor Twellman  NE     F  26  25  2283  16  3    90   55  ...    1
# 3032       Eddie Johnson  KC     F  24  24  2149  15  6    75   43  ...    3
# 3033      Maykel Galindo  CHV    F  28  24  2021  12  5    55   28  ...    2
# ...                  ...  ...  ...  ..  ..   ...  .. ..   ...  ...  ...  ...
# 15762  Alejandro Pozuelo  NaN    M   1   1   120   0  0     5    0  ...    0
# 15763        Franco Jara  NaN    F   2   2   210   0  0     5    1  ...    0
# 15764          Andy Polo  NaN    M   1   1   105   0  0     6    3  ...    0
# 15765    Cristian Roldan  NaN    M   4   4   360   0  0     6    1  ...    0
# 15766       Joevin Jones  NaN  D-M   4   4   260   0  0     8    1  ...    0
#
#       A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season
# 3029     0.04  35  39   21   2   0  59.49  2007     reg
# 3030     0.21  31  20   42   2   1  54.64  2007     reg
# 3031     0.12  13  41   21   2   0  61.11  2007     reg
# 3032     0.25  21  57   50   6   0  57.33  2007     reg
# 3033     0.22  44  53   30   6   0  50.91  2007     reg
# ...       ...  ..  ..  ...  ..  ..    ...   ...     ...
# 15762    0.00   2   0    0   0   0   0.00  2020    post
# 15763    0.00   6   2    3   0   0  20.00  2020    post
# 15764    0.00   0   3    0   0   0  50.00  2020    post
# 15765    0.00   5  11    0   0   0  16.67  2020    post
# 15766    0.00   1   7    0   0   0  12.50  2020    post
#
# [10972 rows x 28 columns]

# %%
player_stats_df['Season'].value_counts()

# %% [markdown]
# I'm going to remove the season column here but before I do that would like to add a feature that tells whether a player made it to the postseason or not. *(If they did do I add their postseason statistics in? What are the arguments for and against?)

# %%
grouped = player_stats_df.groupby(['Player', 'Year'])
made_postseason = grouped['Season'].nunique()

made_postseason = made_postseason.reset_index()
made_postseason.columns = ['Player', 'Year', 'Postseason']

player_stats_df = player_stats_df.merge(made_postseason, on=['Player', 'Year'])
player_stats_df['Postseason'] = player_stats_df['Postseason'].map({2:1, 1:0})
player_stats_df
# Out:
#                Player Club POS  GP  GS  MINS   G  A  SHTS  SOG  ...  A/90min  \
# 0        Roy Lassiter  TB    F  30  30  2580  27  4    76   49  ...     0.14
# 1        Roy Lassiter  TB    F  30  30  2580  27  4    76   49  ...     0.14
# 2        Roy Lassiter  NaN   F   5   5   407   6  0    13   10  ...     0.00
# 3        Roy Lassiter  NaN   F   5   5   407   6  0    13   10  ...     0.00
# 4      Raul Diaz Arce  DC    F  28  28  2351  23  2   100   49  ...     0.08
# ...               ...  ...  ..  ..  ..   ...  .. ..   ...  ...  ...      ...
# 15762    Siem de Jong  CIN   M  15   8   793   0  0    18    5  ...     0.00
# 15763   Maxime Chanot  NYC   D  20  20  1712   0  0    19    4  ...     0.00
# 15764   Maxime Chanot  NaN   D   1   1   120   1  0     2    1  ...     0.00
# 15765   Nicolas Figal  MIA   D  21  21  1746   0  0    22    9  ...     0.00
# 15766   Nicolas Figal  NaN   D   1   1    90   0  0     0    0  ...     0.00
#
#        FC  FS  OFF  YC  RC   SOG%  Year  Season  Postseason
# 0      20  39   70   2   0  64.47  1996     reg           1
# 1      20  39   70   2   0  64.47  1996     reg           1
# 2       5   9    9   2   0  76.92  1996    post           1
# 3       5   9    9   2   0  76.92  1996    post           1
# 4      32  26   35   6   1  49.00  1996     reg           1
# ...    ..  ..  ...  ..  ..    ...   ...     ...         ...
# 15762   7   8    1   0   0  27.78  2020     reg           0
# 15763  18   6    1   5   1  21.05  2020     reg           1
# 15764   1   1    0   0   0  50.00  2020    post           1
# 15765  22  26    0   4   0  40.91  2020     reg           1
# 15766   1   1    0   0   0    NaN  2020    post           1
#
# [15767 rows x 29 columns]

# %%
k_grouped = keeper_stats_df.groupby(['Player', 'Year'])
made_postseason = k_grouped['Season'].nunique()

made_postseason = made_postseason.reset_index()
made_postseason.columns = ['Player', 'Year', 'Postseason']

keeper_stats_df = keeper_stats_df.merge(made_postseason, on=['Player', 'Year'])
keeper_stats_df['Postseason'] = keeper_stats_df['Postseason'].map({2:1, 1:0})
keeper_stats_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Postseason'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[195], line 8
#       5 made_postseason.columns = ['Player', 'Year', 'Postseason']
#       7 keeper_stats_df = keeper_stats_df.merge(made_postseason, on=['Player', 'Year'])
# ----> 8 keeper_stats_df['Postseason'] = keeper_stats_df['Postseason'].map({2:1, 1:0})
#       9 keeper_stats_df
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Postseason'

# %% [markdown]
# Removing postseason data from the dataset as it is a smaller subset and effectively duplicates players that made it to the postseason for that particular year.

# %%
# Filtering dataframes to only have data from the regular season
player_stats_df = player_stats_df[player_stats_df['Season'] == 'reg']
keeper_stats_df = keeper_stats_df[keeper_stats_df['Season'] == 'reg']

# %%
player_stats_df
# Out:
#                  Player Club POS  GP  GS  MINS   G  A  SHTS  SOG  ...  \
# 0        Luciano Emilio  DC    F  29  28  2410  20  1    79   47  ...
# 2      Juan Pablo Angel  NY    F  24  24  2125  19  5    97   53  ...
# 4       Taylor Twellman  NE    F  26  25  2283  16  3    90   55  ...
# 6         Eddie Johnson  KC    F  24  24  2149  15  6    75   43  ...
# 8        Maykel Galindo  CHV   F  28  24  2021  12  5    55   28  ...
# ...                 ...  ...  ..  ..  ..   ...  .. ..   ...  ...  ...
# 10963  Sebastian Mendez  ORL   M  19  11  1087   0  0    17    3  ...
# 10965        Kelyn Rowe   NE   M  16  10   896   0  0    17    4  ...
# 10967      Siem de Jong  CIN   M  15   8   793   0  0    18    5  ...
# 10968     Maxime Chanot  NYC   D  20  20  1712   0  0    19    4  ...
# 10970     Nicolas Figal  MIA   D  21  21  1746   0  0    22    9  ...
#
#        A/90min  FC  FS  OFF  YC  RC   SOG%  Year  Season  Postseason
# 0         0.04  35  39   21   2   0  59.49  2007     reg           1
# 2         0.21  31  20   42   2   1  54.64  2007     reg           1
# 4         0.12  13  41   21   2   0  61.11  2007     reg           1
# 6         0.25  21  57   50   6   0  57.33  2007     reg           1
# 8         0.22  44  53   30   6   0  50.91  2007     reg           1
# ...        ...  ..  ..  ...  ..  ..    ...   ...     ...         ...
# 10963     0.00  32   9    1   4   1  17.65  2020     reg           1
# 10965     0.00  13   4    0   3   0  23.53  2020     reg           1
# 10967     0.00   7   8    1   0   0  27.78  2020     reg           0
# 10968     0.00  18   6    1   5   1  21.05  2020     reg           1
# 10970     0.00  22  26    0   4   0  40.91  2020     reg           1
#
# [7245 rows x 29 columns]

# %%
keeper_stats_df
# Out:
#                 Player Club POS  GP  GS  MINS  SHTS   SV  GA   GAA PKG/A   W  \
# 0       Bouna Coundoul  COL  GK  30  30  2668   158  120  32  1.07   2/2   9
# 1        Kevin Hartman  KC   GK  30  30  2700   159  110  45  1.50   6/7  11
# 3            Matt Reis  NE   GK  30  30  2700   169  120  43  1.43   3/3  14
# 5           Joe Cannon  LA   GK  29  29  2610   171  119  46  1.59   4/5   9
# 6         Troy Perkins  DC   GK  29  29  2610   155  117  32  1.10   1/3  16
# ...                ...  ...  ..  ..  ..   ...   ...  ...  ..   ...   ...  ..
# 1353    Emmanuel Ochoa   SJ  GK   0   0     0     0    0   0  0.00   0/0   0
# 1355   Drake Callender  MIA  GK   0   0     0     0    0   0  0.00   0/0   0
# 1357    Elliot Panicco  NSH  GK   0   0     0     0    0   0  0.00   0/0   0
# 1359         Eric Dick  SKC  GK   0   0     0     0    0   0  0.00   0/0   0
# 1361  Stefan Cleveland  SEA  GK   0   0     0     0    0   0  0.00   0/0   0
#
#        L  T  ShO    W%   Sv%  Year Season  Postseason
# 0     12  8    9  30.0  75.9  2007    reg           0
# 1     12  7    5  36.7  69.2  2007    reg           1
# 3      8  8   10  46.7  71.0  2007    reg           1
# 5     13  7    5  31.0  69.6  2007    reg           0
# 6      6  7    8  55.2  75.5  2007    reg           1
# ...   .. ..  ...   ...   ...   ...    ...         ...
# 1353   0  0    0   0.0   0.0  2020    reg           1
# 1355   0  0    0   0.0   0.0  2020    reg           1
# 1357   0  0    0   0.0   0.0  2020    reg           1
# 1359   0  0    0   0.0   0.0  2020    reg           1
# 1361   0  0    0   0.0   0.0  2020    reg           1
#
# [897 rows x 20 columns]

# %% [markdown]
# The bulk of the data cleaning comes in for the salary dataframes which I am loading in here. I first identified what differences in column names the datasets had and got them to a place of uniformity.

# %%
# Loading in all the salary datasets into respective dataframes
salary2007_df = pd.read_excel('./data/Salary_data/2007-Salaries.xlsx', header=0)
salary2008_df = pd.read_excel('./data/Salary_data/2008-Salaries.xlsx', header=0)
salary2009_df = pd.read_excel('./data/Salary_data/2009-Salaries.xlsx', header=0)
salary2010_df = pd.read_excel('./data/Salary_data/2010-Salaries.xlsx', header=0)
salary2011_df = pd.read_excel('./data/Salary_data/2011-Salaries.xlsx', header=1)
salary2012_df = pd.read_excel('./data/Salary_data/2012-Salaries.xlsx', header=1)
salary2013_df = pd.read_excel('./data/Salary_data/2013-Salaries.xlsx', header=1)
salary2014_df = pd.read_excel('./data/Salary_data/2014-Salaries.xlsx', header=1)
salary2015_df = pd.read_excel('./data/Salary_data/2015-Salaries.xlsx', header=1)
salary2016_df = pd.read_excel('./data/Salary_data/2016-Salaries.xlsx', header=1)
salary2017_df = pd.read_excel('./data/Salary_data/2017-Salaries.xlsx', header=1)
salary2018_df = pd.read_excel('./data/Salary_data/2018-Salaries.xlsx', header=0)
salary2019_df = pd.read_excel('./data/Salary_data/2019-Salaries.xlsx', header=1)
salary2020_df = pd.read_excel('./data/Salary_data/2020-Salaries-.xlsx', header=0)

# %%
salary2007_df.head()
# Out:
#   Club Last Name  First Name  Pos Base Salary Compensation
# 0   DC   Addlery    Nicholas    F       36000        36000
# 1   LA  Albright       Chris  M-D      142500       142500
# 2   NY  Altidore      Josmer    F       85000       108333
# 3  DAL   Alvarez      Arturo    M       32819        46019
# 4   NY     Angel  Juan Pablo    F     1500000      1593750

# %%
salary2008_df.head()
# Out:
#   Club Last Name First Name Pos Base Salary Compensation
# 0   LA  Adzemian     Vardan   D       12900        12900
# 1   LA     Alamo    Charles  GK       12900        12900
# 2   NE  Albright      Chris   D      160000       160000
# 3  HOU   Alcaraz     Johnny   M       12900        12900
# 4   LA     Allen        Ely   F       12900        12900

# %%
salary2009_df.head()
# Out:
#   Club  Last Name First Name  Pos Base Salary Compensation
# 0   NE   Albright      Chris    D      176000       176000
# 1  RSL  Alexandre       Jean    M       34000        34000
# 2   DC      Allen        Ely  F-M       15300        15300
# 3  SEA     Alonso    Osvaldo    M       65000        65000
# 4   NE     Alston      Kevin    D       55000       104000

# %%
salary2010_df.head()
# Out:
#   Club  Last Name First Name Pos Base Salary Compensation
# 0   NY    Agudelo       Juan   F       40000        70000
# 1   KC  Aiyegbusi  Olukorede   D       40000        40000
# 2  COL      Akpan      Andre   F       40000        65000
# 3   NY   Albright      Chris   D       84000        84000
# 4  DAL  Alexander       Eric   M       40000        40000

# %%
salary2011_df.head()
# Out:
#   Club  Last Name   First Name Pos Base Salary Compensation
# 0  COL     Ababio        Eddie   D       32604        32604
# 1  PHI        Adu       Freddy   M      475884       594884
# 2  RSL    Agorsor  Christopher   F       32604        32604
# 3   NY    Agudelo         Juan   F       55000        85000
# 4   KC  Aiyegbusi    Olukorede   D       42000        42000

# %%
# What is Unnamed:5 ?
salary2020_df.head()
# Out:
#       Last Name First Name 2020 Fall Salary List Club Playing Position  \
# 0      Aaronson    Brenden         Philadelphia Union                M
# 1  Abdul-Salaam       Saad              FC Cincinnati                D
# 2           Abu   Mohammed                  DC United                M
# 3      Abubakar      Lalas            Colorado Rapids                D
# 4         Accam      David               Nashville SC                F
#
#   Base Salary  Unnamed: 5 Base Guaranteed Comp.
# 0       85000         NaN                103309
# 1       81375         NaN                 90042
# 2       81375         NaN                 81375
# 3      145000         NaN                154937
# 4      875000         NaN               1002916

# %%
#These are salaries. Went back into the original excel spreadsheet that the dataset is on and found that at one point
#the information for Base Salary gets split into two columns.
salary2020_df['Unnamed: 5'].value_counts()
# Out:
# Unnamed: 5
# 81375.0      8
# 63547.0      8
# 100000.0     2
# 155004.0     1
# 800000.0     1
# 192500.0     1
# 315000.0     1
# 525000.0     1
# 1457148.0    1
# 275000.0     1
# 6000000.0    1
# 750000.0     1
# 185000.0     1
# 500000.0     1
# 85000.0      1
# 200004.0     1
# 151255.0     1
# 166000.0     1
# 730008.0     1
# 210000.0     1
# Name: count, dtype: int64

# %%
#filling rows with  'Base Salary' nulls with the filled in 'Unnamed: 5' salary values
salary2020_df['Base Salary'].fillna(salary2020_df['Unnamed: 5'], inplace=True)
salary2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Last Name                   795 non-null    object
#  1   First Name                  800 non-null    object
#  2   2020 Fall Salary List Club  800 non-null    object
#  3   Playing Position            798 non-null    object
#  4   Base Salary                 800 non-null    object
#  5   Unnamed: 5                  35 non-null     float64
#  6   Base Guaranteed Comp.       800 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 43.9+ KB

# %%
salary2020_df.drop(columns='Unnamed: 5', inplace=True)

# %%
salary2020_df.head()
# Out:
#       Last Name First Name 2020 Fall Salary List Club Playing Position  \
# 0      Aaronson    Brenden         Philadelphia Union                M
# 1  Abdul-Salaam       Saad              FC Cincinnati                D
# 2           Abu   Mohammed                  DC United                M
# 3      Abubakar      Lalas            Colorado Rapids                D
# 4         Accam      David               Nashville SC                F
#
#   Base Salary Base Guaranteed Comp.
# 0       85000                103309
# 1       81375                 90042
# 2       81375                 81375
# 3      145000                154937
# 4      875000               1002916

# %%
# Looks like the column names have been inputted as values in the dataset. When checking the original spreadsheet,
# each page puts the column names at the top. These were converted into rows with the rest of the data accidentally. This
# likely happened with the other dataframes as well.
salary2020_df.describe()
# Out:
#         Last Name  First Name 2020 Fall Salary List Club Playing Position  \
# count         795         800                        800              798
# unique        705         506                         29                9
# top     Last Name  First Name               Nashville SC                M
# freq           22          22                         33              245
#
#         Base Salary  Base Guaranteed Comp.
# count           800                    800
# unique          233                    539
# top           81375                  81375
# freq            140                     89

# %%
# Column names are different and ordered differently, will have to resort. Fortunately, no extra columns.
salary2019_df.head()
# Out:
#                   Club     Last Name First Name Playing Position  \
# 0   Philadelphia Union      Aaronson    Brenden              M-F
# 1  Seattle Sounders FC  Abdul-Salaam       Saad                D
# 2      Colorado Rapids      Abubakar      Lalas                D
# 3        Columbus Crew         Accam      David              M-F
# 4      Colorado Rapids        Acosta     Kellyn              D-M
#
#    CY Salary (Annual)  CY Guaranteed Comp (Annual)
# 0            70000.08                     98309.48
# 1            70250.04                     70250.04
# 2           135000.00                    144937.50
# 3          1010004.00                   1137920.00
# 4           549999.96                    664999.96

# %%
# Interesting, some First name nulls. 
salary2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Club                         714 non-null    object
#  1   Last Name                    714 non-null    object
#  2   First Name                   705 non-null    object
#  3   Playing Position             713 non-null    object
#  4   CY Salary (Annual)           714 non-null    float64
#  5   CY Guaranteed Comp (Annual)  714 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 33.6+ KB

# %%
# Ahh yes, Soccer players love to be known by only their last name. Otherwise, Nani would be known as 
# Luís Carlos Almeida da Cunha ComM (ComM is a Portugese honorific for great acts of service)
# Will have to deal with the nulls somehow and combine first and last name to player to blend with 
# statistics data.
salary2019_df[salary2019_df['First Name'].isna()]
# Out:
#                      Club Last Name First Name Playing Position  \
# 45          Columbus Crew     Artur        NaN              D-M
# 51             Toronto FC      Auro        NaN                D
# 100             FC Dallas   Bressan        NaN                D
# 304    Philadelphia Union   Ilsinho        NaN                M
# 324  San Jose Earthquakes    Judson        NaN              D-M
# 326             LA Galaxy   Juninho        NaN                M
# 328    New York Red Bulls      Kaku        NaN              M-F
# 469       Orlando City SC      Nani        NaN              M-F
# 559       Orlando City SC   Robinho        NaN              M-F
#
#      CY Salary (Annual)  CY Guaranteed Comp (Annual)
# 45            360000.00                    411633.33
# 51            225000.00                    276666.67
# 100           485300.04                    521931.29
# 304           330000.00                    357000.00
# 324           300000.00                    305000.00
# 326           150000.00                    163125.00
# 328           799999.92                    799999.92
# 469          2333333.04                   2486249.70
# 559           198000.00                    205500.00

# %%
# Looks like the column names didnt get added here 
salary2019_df.describe()
# Out:
#        CY Salary (Annual)  CY Guaranteed Comp (Annual)
# count        7.140000e+02                 7.140000e+02
# mean         3.715375e+05                 4.119960e+05
# std          6.275161e+05                 7.071375e+05
# min          5.624460e+04                 5.625000e+04
# 25%          7.087500e+04                 7.756959e+04
# 50%          1.637500e+05                 1.794980e+05
# 75%          4.537530e+05                 4.985530e+05
# max          7.200000e+06                 7.200000e+06

# %%
# Again, difference in column names
salary2018_df.head()
# Out:
#                  Club     Last Name First Name  Pos     Salary  Compensation
# 0  New York Red Bulls         Abang    Anatole    F       68927         68927
# 1    New York City FC  Abdul-Salaam       Saad    D      106480        120230
# 2       Columbus Crew           Abu   Mohammed    M      175008        181258
# 3       Columbus Crew      Abubakar      Lalas    D    68250.04      75750.04
# 4  Philadelphia Union         Accam      David  F-M  1250000.04    1250000.04

# %%
# one First name null
salary2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Club           696 non-null    object
#  1   Last Name      705 non-null    object
#  2   First Name     704 non-null    object
#  3   Pos            705 non-null    object
#  4   Salary         705 non-null    object
#  5   Compensation   705 non-null    object
# dtypes: object(6)
# memory usage: 33.2+ KB

# %%
# Column names in data
salary2018_df.describe()
# Out:
#              Club  Last Name First Name  Pos  Salary   Compensation
# count         696        705        704  705      705            705
# unique         26        647        445    9      294            519
# top     FC Dallas  Last Name      Chris    M    67500          67500
# freq           34         11         15  230       72             49

# %%
#difference in column names
salary2017_df.head()
# Out:
#    Club     Last Name        First Name  Pos Base Salary Compensation
# 0  NYRB         Abang           Anatole    F       65625        65625
# 1    KC  Abdul-Salaam              Saad    D       96800       110550
# 2   CLB           Abu          Mohammed    M      165000       171250
# 3   CLB      Abubakar  Alhassan "Lalas"    D    65000.04     72500.04
# 4   CHI         Accam             David  F-M      750000     820937.5

# %%
# First name and Last name nulls
salary2017_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678 entries, 0 to 677
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          666 non-null    object
#  1   Last Name     666 non-null    object
#  2   First Name    661 non-null    object
#  3   Pos           666 non-null    object
#  4   Base Salary   678 non-null    object
#  5   Compensation  678 non-null    object
# dtypes: object(6)
# memory usage: 31.9+ KB

# %%
#column names in data
salary2017_df.describe()
# Out:
#        Club  Last Name First Name  Pos  Base Salary  Compensation
# count   666        666        661  666          678           678
# unique   25        604        406   11          268           457
# top     VAN  Last Name      Chris    M        53004         53004
# freq     34         12         14  227           52            43

# %%
salary2016_df.head()
# Out:
#    Club     Last Name First Name  Pos Base Salary Compensation
# 0  NYRB         Abang    Anatole    F       62500        62500
# 1    KC  Abdul-Salaam       Saad    D       63000        76750
# 2   CHI         Accam      David  F-M      700000     770937.5
# 3   RSL        Acosta     Danilo    M       62500        62500
# 4   DAL        Acosta     Kellyn    M      220000       240000

# %%
# First and Last name nulls
salary2016_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          592 non-null    object
#  1   Last Name     597 non-null    object
#  2   First Name    596 non-null    object
#  3   Pos           597 non-null    object
#  4   Base Salary   608 non-null    object
#  5   Compensation  608 non-null    object
# dtypes: object(6)
# memory usage: 28.6+ KB

# %%
# column names in data
salary2016_df.describe()
# Out:
#        Club  Last Name First Name  Pos  Base Salary  Compensation
# count   592        597        596  597          608           608
# unique   23        538        373   11          210           401
# top      DC  Last Name      Chris    M        63000         63000
# freq     31         11         14  195           39            31

# %%
salary2015_df.head()
# Out:
#   Club     Last Name First Name Pos Base Salary Compensation
# 0   NY         Abang    Anatole   F       50000        50000
# 1   KC  Abdul-Salaam       Saad   D       60000        73750
# 2  CHI         Accam      David   F      650000     720937.5
# 3  DAL        Acosta     Kellyn   M       60000        84000
# 4  VAN      Adekugbe     Samuel   D       60000        65000

# %%
# First and last name nulls
salary2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          580 non-null    object
#  1   Last Name     584 non-null    object
#  2   First Name    580 non-null    object
#  3   Pos           583 non-null    object
#  4   Base Salary   594 non-null    object
#  5   Compensation  594 non-null    object
# dtypes: object(6)
# memory usage: 28.0+ KB

# %%
# column names in data
salary2015_df.describe()
# Out:
#        Club  Last Name First Name  Pos  Base Salary  Compensation
# count   580        584        580  583          594           594
# unique   22        533        372   15          175           353
# top     SEA  Last Name      Chris    M        60000         60000
# freq     32         10         13  198          149            93

# %%
salary2014_df.head()
# Out:
#   Club      Last Name First Name Pos Base Salary Compensation
# 0  DAL         Acosta     Kellyn   M       55000        79000
# 1  VAN       Adekugbe     Samuel   D       50000        55000
# 2  POR            Adi    Fanendo   F      580800       593300
# 3  COL  Agbossoumonde       Gale   D       48825     55491.67
# 4  DAL       Akindele      Tesho   F       48500        48500

# %%
# First and last name nulls
salary2014_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          579 non-null    object
#  1   Last Name     582 non-null    object
#  2   First Name    578 non-null    object
#  3   Pos           582 non-null    object
#  4   Base Salary   592 non-null    object
#  5   Compensation  592 non-null    object
# dtypes: object(6)
# memory usage: 27.9+ KB

# %%
# columns names in data
salary2014_df.describe()
# Out:
#        Club  Last Name First Name  Pos  Base Salary  Compensation
# count   579        582        578  582          592           592
# unique   23        530        358   15          178           365
# top     MTL  Last Name      Chris    M        48500         48500
# freq     32         10         13  181           49            35

# %%
salary2013_df.head()
# Out:
#   Club      Last Name First Name Pos Base Salary Compensation
# 0  VAN       Abdallah      Aminu   M       46500        46500
# 1  DAL         Acosta     Kellyn   M       46500        70500
# 2  VAN       Adekugbe     Samuel   D       46500        51500
# 3  TOR  Agbossoumonde       Gale   D       46500     53166.67
# 4   NE        Agudelo       Juan   F      145000       175000

# %%
# First and last name nulls
salary2013_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          583 non-null    object
#  1   Last Name     586 non-null    object
#  2   First Name    584 non-null    object
#  3   Pos           586 non-null    object
#  4   Base Salary   596 non-null    object
#  5   Compensation  596 non-null    object
# dtypes: object(6)
# memory usage: 28.1+ KB

# %%
# column names in data
salary2013_df.describe()
# Out:
#        Club  Last Name First Name  Pos  Base Salary  Compensation
# count   583        586        584  586          596           596
# unique   21        530        373   15          191           369
# top     CHI  Last Name    Michael    M        46500         46500
# freq     33         10         12  192          104            76

# %%
salary2012_df.head()
# Out:
#   Club  Last Name First Name Pos Base Salary Compensation
# 0  PHI        Adu     Freddy   M      400000       519000
# 1  CHV    Agudelo       Juan   F       70000       100000
# 2   KC  Aiyegbusi  Olukorede   D       44100        44100
# 3  COL      Akpan      Andre   F       57200        57200
# 4  PHI   Albright      Chris   D       55000        55000

# %%
#First and last name nulls
salary2012_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          562 non-null    object
#  1   Last Name     564 non-null    object
#  2   First Name    562 non-null    object
#  3   Pos           564 non-null    object
#  4   Base Salary   574 non-null    object
#  5   Compensation  574 non-null    object
# dtypes: object(6)
# memory usage: 27.0+ KB

# %%
# Column names in data
salary2012_df.describe()
# Out:
#        Club  Last Name First Name  Pos  Base Salary  Compensation
# count   562        564        562  564          574           574
# unique   22        515        352   14          176           367
# top     POR  Last Name      Chris    M        44000         33750
# freq     32         10         13  188           53            39

# %% [markdown]
# Here I identified an issue where despite the appearance of the column name, running code based on that name did nothing.

# %%
# This didnt work.
salary2018_df.rename(columns={'Salary': 'Base Salary'}, inplace=True)
salary2018_df
# Out:
#                      Club     Last Name First Name  Pos     Salary   \
# 0      New York Red Bulls         Abang    Anatole    F       68927
# 1        New York City FC  Abdul-Salaam       Saad    D      106480
# 2           Columbus Crew           Abu   Mohammed    M      175008
# 3           Columbus Crew      Abubakar      Lalas    D    68250.04
# 4      Philadelphia Union         Accam      David  F-M  1250000.04
# ..                    ...           ...        ...  ...         ...
# 700             FC Dallas       Ziegler       Reto    D      750000
# 701                  LAFC     Zimmerman     Walker    D      235000
# 702        Atlanta United         Zizzo        Sal    D   129999.96
# 703             FC Dallas        Zobeck       Kyle   GK       67500
# 704  Sporting Kansas City          Zusi     Graham    D      750000
#
#     Compensation
# 0           68927
# 1          120230
# 2          181258
# 3        75750.04
# 4      1250000.04
# ..            ...
# 700        800000
# 701        235000
# 702     129999.96
# 703         67500
# 704     782102.27
#
# [705 rows x 6 columns]

# %% [markdown]
# In order to resolve the above issue, I first created a dictionary of all the salary dataframes so I could clean them all at once.

# %%
# create a dicitonary to iterate over all dataframes 
salary_dict = {"2007": salary2007_df, "2008": salary2008_df, "2009": salary2009_df, "2010": salary2010_df, 
               "2011": salary2011_df, "2012": salary2012_df, "2013": salary2013_df, "2014": salary2014_df, 
               "2015": salary2015_df, "2016": salary2016_df, "2017": salary2017_df, "2018": salary2018_df,
               "2019": salary2019_df, "2020": salary2020_df}

# %% [markdown]
# I strip all whitespace from the column names and can now change those column names without a problem.

# %%
# When attempting to call certain column names, received errors saying they didnt exist. 
# Strpping white space to try to fix this
for year in salary_dict.keys():
    salary_dict[year].columns = salary_dict[year].columns.str.strip()

# %%
# Renaming columns for consistency
salary2018_df.rename(columns={'Salary': 'Base Salary'}, inplace=True)
salary2018_df
# Out:
#                      Club     Last Name First Name  Pos Base Salary  \
# 0      New York Red Bulls         Abang    Anatole    F       68927
# 1        New York City FC  Abdul-Salaam       Saad    D      106480
# 2           Columbus Crew           Abu   Mohammed    M      175008
# 3           Columbus Crew      Abubakar      Lalas    D    68250.04
# 4      Philadelphia Union         Accam      David  F-M  1250000.04
# ..                    ...           ...        ...  ...         ...
# 700             FC Dallas       Ziegler       Reto    D      750000
# 701                  LAFC     Zimmerman     Walker    D      235000
# 702        Atlanta United         Zizzo        Sal    D   129999.96
# 703             FC Dallas        Zobeck       Kyle   GK       67500
# 704  Sporting Kansas City          Zusi     Graham    D      750000
#
#     Compensation
# 0          68927
# 1         120230
# 2         181258
# 3       75750.04
# 4     1250000.04
# ..           ...
# 700       800000
# 701       235000
# 702    129999.96
# 703        67500
# 704    782102.27
#
# [705 rows x 6 columns]

# %%
salary_dict["2018"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Club          696 non-null    object
#  1   Last Name     705 non-null    object
#  2   First Name    704 non-null    object
#  3   Pos           705 non-null    object
#  4   Base Salary   705 non-null    object
#  5   Compensation  705 non-null    object
# dtypes: object(6)
# memory usage: 33.2+ KB

# %%
salary2019_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Club                         714 non-null    object
#  1   Last Name                    714 non-null    object
#  2   First Name                   705 non-null    object
#  3   Playing Position             713 non-null    object
#  4   CY Salary (Annual)           714 non-null    float64
#  5   CY Guaranteed Comp (Annual)  714 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 33.6+ KB

# %%
#Renaming columns for consistency
salary2019_df.rename(columns={'Playing Position': 'Pos', 'CY Salary (Annual)': 'Base Salary',
                              'CY Guaranteed Comp (Annual)': 'Compensation'}, inplace=True)

# %%
salary2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Last Name                   795 non-null    object
#  1   First Name                  800 non-null    object
#  2   2020 Fall Salary List Club  800 non-null    object
#  3   Playing Position            798 non-null    object
#  4   Base Salary                 800 non-null    object
#  5   Base Guaranteed Comp.       800 non-null    object
# dtypes: object(6)
# memory usage: 37.6+ KB

# %%
#Renaming columns for consistency
salary2020_df.rename(columns={'Playing Position': 'Pos', '2020 Fall Salary List Club': 'Club'}, inplace=True)

# %%
#Starting year at 2012, same as our statistics dataframes
df_year = 2007
for year in salary_dict.keys():
    # adding year column to each dataframe in salary_dict
    salary_dict.get(year, {})['year'] = df_year
    df_year+=1

# %%
salary2007_df.head()
# Out:
#   Club Last Name  First Name  Pos Base Salary Compensation  year
# 0   DC   Addlery    Nicholas    F       36000        36000  2007
# 1   LA  Albright       Chris  M-D      142500       142500  2007
# 2   NY  Altidore      Josmer    F       85000       108333  2007
# 3  DAL   Alvarez      Arturo    M       32819        46019  2007
# 4   NY     Angel  Juan Pablo    F     1500000      1593750  2007

# %%
salary2015_df.head()
# Out:
#   Club     Last Name First Name Pos Base Salary Compensation  year
# 0   NY         Abang    Anatole   F       50000        50000  2015
# 1   KC  Abdul-Salaam       Saad   D       60000        73750  2015
# 2  CHI         Accam      David   F      650000     720937.5  2015
# 3  DAL        Acosta     Kellyn   M       60000        84000  2015
# 4  VAN      Adekugbe     Samuel   D       60000        65000  2015

# %%
# Rearranging order of columns for consistency
salary2020_df = pd.DataFrame(salary2020_df, columns=['Club', 'Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'year'])
salary2020_df
# Out:
#                      Club     Last Name First Name Pos Base Salary  \
# 0      Philadelphia Union      Aaronson    Brenden   M       85000
# 1           FC Cincinnati  Abdul-Salaam       Saad   D       81375
# 2               DC United           Abu   Mohammed   M       81375
# 3         Colorado Rapids      Abubakar      Lalas   D      145000
# 4            Nashville SC         Accam      David   F      875000
# ..                    ...           ...        ...  ..         ...
# 795    New York Red Bulls           NaN       Kaku   M      850000
# 796       Orlando City SC           NaN    Robinho   M      198000
# 797    Philadelphia Union           NaN    Ilsinho   M      425000
# 798  San Jose Earthquakes           NaN     Judson   M      320000
# 799            Toronto FC           NaN       Auro   D      300000
#
#     Base Guaranteed Comp.  year
# 0                  103309  2020
# 1                   90042  2020
# 2                   81375  2020
# 3                  154937  2020
# 4                 1002916  2020
# ..                    ...   ...
# 795                850000  2020
# 796                205500  2020
# 797                476250  2020
# 798                325000  2020
# 799                328750  2020
#
# [800 rows x 7 columns]

# %%
for year, df in salary_dict.items():
    # Remove columns i dont need
    salary_dict[year] = salary_dict[year].drop(['Club'], axis=1)

# %%
salary_dict['2012'].head()
# Out:
#    Last Name First Name Pos Base Salary Compensation  year
# 0        Adu     Freddy   M      400000       519000  2012
# 1    Agudelo       Juan   F       70000       100000  2012
# 2  Aiyegbusi  Olukorede   D       44100        44100  2012
# 3      Akpan      Andre   F       57200        57200  2012
# 4   Albright      Chris   D       55000        55000  2012

# %%
# Renaming columns to remove issue where columns cant be called because of hidden characters.
salary_dict['2007'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2008'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2009'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2010'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2011'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2012'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2013'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2014'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2015'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2016'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2017'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2018'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2019'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']
salary_dict['2020'].columns = ['Last Name', 'First Name', 'Pos', 'Base Salary', 'Base Guaranteed Comp.', 'Year']

# %%
# Now that all salary dataframes are consistent, we can combine into one dataframe vertically.
salary_df = pd.concat(salary_dict, ignore_index=True)  
salary_df
# Out:
#      Last Name  First Name  Pos Base Salary Base Guaranteed Comp.  Year
# 0      Addlery    Nicholas    F       36000                 36000  2007
# 1     Albright       Chris  M-D      142500                142500  2007
# 2     Altidore      Josmer    F       85000                108333  2007
# 3      Alvarez      Arturo    M       32819                 46019  2007
# 4        Angel  Juan Pablo    F     1500000               1593750  2007
# ...        ...         ...  ...         ...                   ...   ...
# 8007       NaN        Kaku    M      850000                850000  2020
# 8008       NaN     Robinho    M      198000                205500  2020
# 8009       NaN     Ilsinho    M      425000                476250  2020
# 8010       NaN      Judson    M      320000                325000  2020
# 8011       NaN        Auro    D      300000                328750  2020
#
# [8012 rows x 6 columns]

# %%
# GK must be split because they have different statistics data.
salary_df['Pos'].value_counts()
# Out:
# Pos
# M                   2449
# D                   2242
# F                   1563
# GK                   883
# M-F                  298
# D-M                  178
# Pos                  110
# M-D                   74
# F-M                   63
# Playing Position      22
# M/F                   20
# M/D                    9
# MF                     7
# D/M                    6
# F/M                    6
# D/F                    4
# F-D                    1
# D-F                    1
# Name: count, dtype: int64

# %%
# Creating player_salary_df without GK data
player_salary_df = salary_df[salary_df['Pos'] != 'GK']
player_salary_df
# Out:
#      Last Name  First Name  Pos Base Salary Base Guaranteed Comp.  Year
# 0      Addlery    Nicholas    F       36000                 36000  2007
# 1     Albright       Chris  M-D      142500                142500  2007
# 2     Altidore      Josmer    F       85000                108333  2007
# 3      Alvarez      Arturo    M       32819                 46019  2007
# 4        Angel  Juan Pablo    F     1500000               1593750  2007
# ...        ...         ...  ...         ...                   ...   ...
# 8007       NaN        Kaku    M      850000                850000  2020
# 8008       NaN     Robinho    M      198000                205500  2020
# 8009       NaN     Ilsinho    M      425000                476250  2020
# 8010       NaN      Judson    M      320000                325000  2020
# 8011       NaN        Auro    D      300000                328750  2020
#
# [7129 rows x 6 columns]

# %%
# Dropping rows where both First and Last name are null
player_salary_df.dropna(subset=['First Name', 'Last Name'], how='all', inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/2983055035.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_salary_df.dropna(subset=['First Name', 'Last Name'], how='all', inplace=True)

# %%
player_salary_df.isna().sum()
# Out:
# Last Name                 5
# First Name               29
# Pos                       4
# Base Salary               0
# Base Guaranteed Comp.     0
# Year                      0
# dtype: int64

# %%
player_salary_df[player_salary_df['First Name'].isna()]
# Out:
#      Last Name First Name  Pos Base Salary Base Guaranteed Comp.  Year
# 1852  Jeferson        NaN    F      429996                484996  2011
# 2157      Alex        NaN    M       96000                105950  2012
# 2409   Juninho        NaN    M       50000                 65625  2012
# 2734      Alex        NaN    M      110000                119950  2013
# 3003   Juninho        NaN    M      290000                290000  2013
# 3328      Alex        NaN    M      123750                133700  2014
# 3487   Fabinho        NaN    D       96000                100500  2014
# 3592   Juninho        NaN    M      325000                325000  2014
# 3599      Kaka        NaN    M     6660000               7167500  2014
# 3924      Alex        NaN    M      142000                142000  2015
# 4176   Juninho        NaN    M      350000                350000  2015
# 4179      Kaka        NaN    M     6660000               7167500  2015
# 4323     Pecka        NaN    M       60000              64166.67  2015
# 4799      Kaka        NaN    M     6660000               7167500  2016
# 5331   Fabinho        NaN    D      159759                167759  2017
# 5424     Ibson        NaN    M      200004              210337.4  2017
# 5426   Ilsinho        NaN    M      470000             518333.33  2017
# 5449   Juninho        NaN    M      700008             716674.67  2017
# 5450      Kaka        NaN    M     6660000               7167500  2017
# 5844      Auro        NaN    D      200004                272504  2018
# 6543     Artur        NaN  D-M    360000.0             411633.33  2019
# 6549      Auro        NaN    D    225000.0             276666.67  2019
# 6598   Bressan        NaN    D   485300.04             521931.29  2019
# 6802   Ilsinho        NaN    M    330000.0              357000.0  2019
# 6822    Judson        NaN  D-M    300000.0              305000.0  2019
# 6824   Juninho        NaN    M    150000.0              163125.0  2019
# 6826      Kaku        NaN  M-F   799999.92             799999.92  2019
# 6967      Nani        NaN  M-F  2333333.04             2486249.7  2019
# 7057   Robinho        NaN  M-F    198000.0              205500.0  2019

# %%
# Had to get creative, just making first and last name the same for players that only have one to be able to merge 
# first and last name
for i, player in player_salary_df.iterrows():
    if pd.isnull(player['First Name']):
        player_salary_df.at[i, 'First Name'] = player_salary_df.at[i, 'Last Name']
    if pd.isnull(player['Last Name']):
        player_salary_df.at[i, 'Last Name'] = player_salary_df.at[i, 'First Name']

# %%
player_salary_df[player_salary_df['First Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Last Name, First Name, Pos, Base Salary, Base Guaranteed Comp., Year]
# Index: []

# %%
for i, player in player_salary_df.iterrows():
    if player_salary_df.at[i, 'First Name'] == player_salary_df.at[i, 'Last Name']:
        # For rows where first and last name are the same, player name equals just the last name
        player_salary_df.at[i, 'Player'] = player_salary_df.at[i, 'Last Name']
    else:
        # player name equals first name plus last name for all other players 
        player_salary_df.at[i, 'Player'] = player_salary_df.at[i, 'First Name'] + " " +  player_salary_df.at[i, 'Last Name']
# Drop first name, last name, and position
player_salary_df.drop(columns=['First Name', 'Last Name', 'Pos'], inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/644187849.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_salary_df.at[i, 'Player'] = player_salary_df.at[i, 'First Name'] + " " +  player_salary_df.at[i, 'Last Name']
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/644187849.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Nicholas Addlery' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   player_salary_df.at[i, 'Player'] = player_salary_df.at[i, 'First Name'] + " " +  player_salary_df.at[i, 'Last Name']
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/644187849.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_salary_df.drop(columns=['First Name', 'Last Name', 'Pos'], inplace=True)

# %%
player_salary_df
# Out:
#      Base Salary Base Guaranteed Comp.  Year            Player
# 0          36000                 36000  2007  Nicholas Addlery
# 1         142500                142500  2007    Chris Albright
# 2          85000                108333  2007   Josmer Altidore
# 3          32819                 46019  2007    Arturo Alvarez
# 4        1500000               1593750  2007  Juan Pablo Angel
# ...          ...                   ...   ...               ...
# 8007      850000                850000  2020              Kaku
# 8008      198000                205500  2020           Robinho
# 8009      425000                476250  2020           Ilsinho
# 8010      320000                325000  2020            Judson
# 8011      300000                328750  2020              Auro
#
# [7057 rows x 4 columns]

# %%
#Create keeper_salary_df, containing data for only GK
keeper_salary_df = salary_df[salary_df['Pos'] == 'GK']
keeper_salary_df
# Out:
#       Last Name First Name Pos Base Salary Base Guaranteed Comp.  Year
# 33        Burpo    Preston  GK     52491.6               52491.6  2007
# 34        Burse        Ray  GK       17700                 17700  2007
# 35        Busch        Jon  GK       58008                 58008  2007
# 41       Cannon        Joe  GK      192000                192000  2007
# 48       Cepero      Danny  GK       12900                 12900  2007
# ...         ...        ...  ..         ...                   ...   ...
# 7973   Westberg    Quentin  GK      240000                253333  2020
# 7979     Willis        Joe  GK      180000                187833  2020
# 7989  Yarbrough    William  GK      120000                120000  2020
# 7999   Zendejas     Adrian  GK       81375                 81375  2020
# 8002     Zobeck       Kyle  GK       81375                 81375  2020
#
# [883 rows x 6 columns]

# %%
# Keeper player name  equals first name plus last name
keeper_salary_df['Player'] = keeper_salary_df['First Name'] + " " + keeper_salary_df['Last Name']
# drop first name, last name, and position
keeper_salary_df.drop(columns=['First Name', 'Last Name', 'Pos'], inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/3645307494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keeper_salary_df['Player'] = keeper_salary_df['First Name'] + " " + keeper_salary_df['Last Name']
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/3645307494.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keeper_salary_df.drop(columns=['First Name', 'Last Name', 'Pos'], inplace=True)

# %%
# Creating a normalize_string function to clean Player column strings to combine stats  and salary dataframes on player and year
def normalize_string(string):
    normalized = unidecode(string)
    re.sub(r'[^A-Za-z0-9\s]+', '', string)
    return re.sub(r'[^\w\s]', '', normalized)

# %%
# apply function to player stats and salary df's
player_stats_df['Player'] = player_stats_df['Player'].apply(normalize_string)
player_salary_df['Player'] = player_salary_df['Player'].apply(normalize_string)
# change all strings to lowercase
player_stats_df['Player'] = player_stats_df['Player'].str.lower()
player_salary_df['Player'] = player_salary_df['Player'].str.lower()
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/2746037855.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_df['Player'] = player_stats_df['Player'].apply(normalize_string)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/2746037855.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_salary_df['Player'] = player_salary_df['Player'].apply(normalize_string)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/2746037855.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_df['Player'] = player_stats_df['Player'].str.lower()
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/2746037855.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_salary_df['Player'] = player_salary_df['Player'].str.lower()

# %%
#Create lists for comparison
left_player_name = []
fuzz_player_name = []
# Looping over each player name in stats_df to compare to every player name in salary_df using fuzz. Once the string with the
# highest similarity is found, stats_df player name is changed to the closest match.
for i, player in player_stats_df.iterrows():
    left_player = player['Player']
    left_player_name.append(left_player)
    closest_match = None
    highest_similarity = 0

    for _, right_player in player_salary_df.iterrows():
        right_player_1 = right_player['Player']
        similarity = fuzz.ratio(left_player, right_player_1)

        if similarity > highest_similarity:
            highest_similarity = similarity
            closest_match = right_player_1
            
    if highest_similarity < 80: 
        fuzz_player_name.append(left_player)
    else:
        fuzz_player_name.append(closest_match)
        player_stats_df.at[i, 'Player'] = closest_match

# %%
#creating a fuzz df to see how fuzz did
fuzz_df = pd.DataFrame({'Left Name': left_player_name,
                        'Fuzz Name': fuzz_player_name})
fuzz_df
# Out:
#              Left Name            Fuzz Name
# 0       luciano emilio       luciano emilio
# 1     juan pablo angel     juan pablo angel
# 2      taylor twellman      taylor twellman
# 3        eddie johnson        eddie johnson
# 4       maykel galindo       maykel galindo
# ...                ...                  ...
# 7240  sebastian mendez  sebastian fernandez
# 7241        kelyn rowe           kelyn rowe
# 7242      siem de jong         siem de jong
# 7243     maxime chanot        maxime chanot
# 7244     nicolas figal        nicolas figal
#
# [7245 rows x 2 columns]

# %%
# creating a bad_fuzz df to see which names did not match up.
# Unfortunately it looks like there is potentially good data getting thrown in here but there are also bad matches. Throwing
# these datasets out will keep most of our data intact
bad_fuzz = fuzz_df[fuzz_df['Left Name'] != fuzz_df['Fuzz Name']]
bad_fuzz
# Out:
#               Left Name              Fuzz Name
# 22    dwayne de rosario       dwayne derosario
# 25         danny dichio          daniel dichio
# 26      jeff cunningham     jeffrey cunningham
# 75     jose burciaga jr          jose burciaga
# 99           andy welsh           andrew welsh
# ...                 ...                    ...
# 7160       aljaz struna      aljaz kiki struna
# 7198     jeizon ramirez  jeizon ramirez chacon
# 7221     miguel ibarra           miguel ibarra
# 7225        matias vera            matias jara
# 7240   sebastian mendez    sebastian fernandez
#
# [291 rows x 2 columns]

# %%
fuzz.ratio('sebastian mendez', 'sebastian fernandez')
# Out:
# 85.71428571428572

# %%
# merging keeper stats and salary df's 
keeper_stats_salaries_df = pd.merge(keeper_stats_df, keeper_salary_df, how='left',
                                    left_on=['Player', 'Year'], right_on=['Player', 'Year'])
keeper_stats_salaries_df
# Out:
#                Player Club POS  GP  GS  MINS  SHTS   SV  GA   GAA  ...   L  T  \
# 0      Bouna Coundoul  COL  GK  30  30  2668   158  120  32  1.07  ...  12  8
# 1       Kevin Hartman  KC   GK  30  30  2700   159  110  45  1.50  ...  12  7
# 2           Matt Reis  NE   GK  30  30  2700   169  120  43  1.43  ...   8  8
# 3          Joe Cannon  LA   GK  29  29  2610   171  119  46  1.59  ...  13  7
# 4        Troy Perkins  DC   GK  29  29  2610   155  117  32  1.10  ...   6  7
# ..                ...  ...  ..  ..  ..   ...   ...  ...  ..   ...  ...  .. ..
# 892    Emmanuel Ochoa   SJ  GK   0   0     0     0    0   0  0.00  ...   0  0
# 893   Drake Callender  MIA  GK   0   0     0     0    0   0  0.00  ...   0  0
# 894    Elliot Panicco  NSH  GK   0   0     0     0    0   0  0.00  ...   0  0
# 895         Eric Dick  SKC  GK   0   0     0     0    0   0  0.00  ...   0  0
# 896  Stefan Cleveland  SEA  GK   0   0     0     0    0   0  0.00  ...   0  0
#
#      ShO    W%   Sv%  Year  Season  Postseason Base Salary  \
# 0      9  30.0  75.9  2007     reg           0       30000
# 1      5  36.7  69.2  2007     reg           1      150000
# 2     10  46.7  71.0  2007     reg           1      150000
# 3      5  31.0  69.6  2007     reg           0      192000
# 4      8  55.2  75.5  2007     reg           1       85000
# ..   ...   ...   ...   ...     ...         ...         ...
# 892    0   0.0   0.0  2020     reg           1       63547
# 893    0   0.0   0.0  2020     reg           1      100000
# 894    0   0.0   0.0  2020     reg           1       63547
# 895    0   0.0   0.0  2020     reg           1       81375
# 896    0   0.0   0.0  2020     reg           1       81375
#
#      Base Guaranteed Comp.
# 0                    30000
# 1                   150000
# 2                   150000
# 3                   192000
# 4                    87500
# ..                     ...
# 892                  73759
# 893                 100000
# 894                  63547
# 895                  85020
# 896                  81375
#
# [897 rows x 22 columns]

# %%
# Some nulls in Salary
keeper_stats_salaries_df.isna().sum()
# Out:
# Player                     0
# Club                       0
# POS                        0
# GP                         0
# GS                         0
# MINS                       0
# SHTS                       0
# SV                         0
# GA                         0
# GAA                        0
# PKG/A                      0
# W                          0
# L                          0
# T                          0
# ShO                        0
# W%                         0
# Sv%                        0
# Year                       0
# Season                     0
# Postseason                 0
# Base Salary              107
# Base Guaranteed Comp.    107
# dtype: int64

# %%
player_stats_salaries_df = pd.merge(player_stats_df, player_salary_df, how='left', 
                                    left_on=['Player', 'Year'], right_on=['Player', 'Year'])
player_stats_salaries_df
# Out:
#                    Player Club POS  GP  GS  MINS   G  A  SHTS  SOG  ...  FS  \
# 0          luciano emilio  DC    F  29  28  2410  20  1    79   47  ...  39
# 1        juan pablo angel  NY    F  24  24  2125  19  5    97   53  ...  20
# 2         taylor twellman  NE    F  26  25  2283  16  3    90   55  ...  41
# 3           eddie johnson  KC    F  24  24  2149  15  6    75   43  ...  57
# 4          maykel galindo  CHV   F  28  24  2021  12  5    55   28  ...  53
# ...                   ...  ...  ..  ..  ..   ...  .. ..   ...  ...  ...  ..
# 7240  sebastian fernandez  ORL   M  19  11  1087   0  0    17    3  ...   9
# 7241           kelyn rowe   NE   M  16  10   896   0  0    17    4  ...   4
# 7242         siem de jong  CIN   M  15   8   793   0  0    18    5  ...   8
# 7243        maxime chanot  NYC   D  20  20  1712   0  0    19    4  ...   6
# 7244        nicolas figal  MIA   D  21  21  1746   0  0    22    9  ...  26
#
#      OFF  YC  RC   SOG%  Year  Season  Postseason  Base Salary  \
# 0     21   2   0  59.49  2007     reg           1       265000
# 1     42   2   1  54.64  2007     reg           1      1500000
# 2     21   2   0  61.11  2007     reg           1       325008
# 3     50   6   0  57.33  2007     reg           1       750000
# 4     30   6   0  50.91  2007     reg           1        72500
# ...   ..  ..  ..    ...   ...     ...         ...          ...
# 7240   1   4   1  17.65  2020     reg           1          NaN
# 7241   0   3   0  23.53  2020     reg           1       310610
# 7242   1   0   0  27.78  2020     reg           0      1157556
# 7243   1   5   1  21.05  2020     reg           1       725000
# 7244   0   4   0  40.91  2020     reg           1          NaN
#
#       Base Guaranteed Comp.
# 0                    293125
# 1                   1593750
# 2                    350008
# 3                    875000
# 4                     72500
# ...                     ...
# 7240                    NaN
# 7241                 310610
# 7242                1287556
# 7243                 725000
# 7244                    NaN
#
# [7245 rows x 31 columns]

# %%
#Some nulls to deal with
player_stats_salaries_df.isna().sum()
# Out:
# Player                      0
# Club                        0
# POS                         0
# GP                          0
# GS                          0
# MINS                        0
# G                           0
# A                           0
# SHTS                        0
# SOG                         0
# GWG                         0
# PKG/A                       0
# HmG                         0
# RdG                         0
# G/90min                     0
# SC%                         0
# GWA                         0
# HmA                         0
# RdA                         0
# A/90min                     0
# FC                          0
# FS                          0
# OFF                         0
# YC                          0
# RC                          0
# SOG%                     1528
# Year                        0
# Season                      0
# Postseason                  0
# Base Salary               777
# Base Guaranteed Comp.     777
# dtype: int64

# %%
player_stats_salaries_df[player_stats_salaries_df['Base Salary'].isna()].head(30)
# Out:
#                  Player Club  POS  GP  GS  MINS   G  A  SHTS  SOG  ...  FS  \
# 6       christian gomez  DC     M  27  27  2272  10  9    82   44  ...  43
# 7         jozy altidore  TOR    F  22  15  1399   9  4    43   20  ...  43
# 9        robbie findley  LA     F  25  14  1353   8  0    31   16  ...  27
# 10                 fred  DC     M  26  23  2096   7  8    28   14  ...  40
# 27            juan toja  DAL    M  27  27  2388   6  1    33   16  ...  41
# 45       herculez gomez  COL    F  20  16  1537   4  2    51   22  ...  46
# 65        roberto brown  COL    F  13   8   696   3  0    14    4  ...  11
# 83     fabian espindola  RSL    F  12   8   602   2  2    13    9  ...  16
# 109          freddy adu  RSL    F  11  10   899   1  2    24   12  ...  25
# 116    willian oliveira  CHI    M   8   4   381   1  1     7    4  ...   6
# 129    john thorrington  CHI    M   2   0    31   1  0     2    2  ...   0
# 136         matt taylor  CHV    F  11   0   156   1  0     5    5  ...   3
# 146            denilson  DAL    M   8   7   606   1  0    14    4  ...  21
# 170       bobby boswell  DC     D  23  22  1963   0  2     7    2  ...   4
# 173     guyroland kpene  DC     F  15   8   626   0  2    18   12  ...  10
# 175       taylor graham  NY     D   5   3   335   0  1     0    0  ...   4
# 176  kasali yinka casal  DC     M   4   0   104   0  1     0    0  ...   3
# 189          ricardinho  DAL    F   8   3   279   0  1     5    2  ...   7
# 194              thiago  CHI    M  13   5   568   0  1    10    3  ...   4
# 205   yherland mcdonald  COL    M   0   0     0   0  0     0    0  ...   0
# 206            tim ream  NY     D   3   2   142   0  0     0    0  ...   3
# 207         rich asante  TOR    M   0   0     0   0  0     0    0  ...   0
# 214        joey worthen  RSL  F-M   0   0     0   0  0     0    0  ...   0
# 215         julian nash  HOU    F   0   0     0   0  0     0    0  ...   0
# 224    tommy krizanovic  DAL    F   0   0     0   0  0     0    0  ...   0
# 227      mike sambursky  HOU    F   0   0     0   0  0     0    0  ...   0
# 229      aaron chandler  CLB  M-F   0   0     0   0  0     0    0  ...   0
# 234         john nelson  DC     D   0   0     0   0  0     0    0  ...   0
# 238         kiki willis  DC     M   0   0     0   0  0     0    0  ...   0
# 241          aj godbolt  KC     M   0   0     0   0  0     0    0  ...   0
#
#     OFF  YC  RC    SOG%  Year  Season  Postseason  Base Salary  \
# 6    10   6   0   53.66  2007     reg           1          NaN
# 7    12   4   0   46.51  2007     reg           1          NaN
# 9    14   0   0   51.61  2007     reg           0          NaN
# 10   21   5   1   50.00  2007     reg           1          NaN
# 27    6   4   0   48.48  2007     reg           1          NaN
# 45   17   6   0   43.14  2007     reg           0          NaN
# 65   16   2   1   28.57  2007     reg           0          NaN
# 83    7   3   1   69.23  2007     reg           0          NaN
# 109   6   1   0   50.00  2007     reg           0          NaN
# 116   3   0   0   57.14  2007     reg           0          NaN
# 129   0   0   0  100.00  2007     reg           1          NaN
# 136   3   0   0  100.00  2007     reg           0          NaN
# 146   2   3   0   28.57  2007     reg           1          NaN
# 170   0   5   1   28.57  2007     reg           1          NaN
# 173   8   2   0   66.67  2007     reg           1          NaN
# 175   0   0   0     NaN  2007     reg           0          NaN
# 176   1   1   0     NaN  2007     reg           0          NaN
# 189   3   0   0   40.00  2007     reg           1          NaN
# 194   2   3   0   30.00  2007     reg           0          NaN
# 205   0   0   0     NaN  2007     reg           0          NaN
# 206   0   0   0     NaN  2007     reg           0          NaN
# 207   0   0   0     NaN  2007     reg           0          NaN
# 214   0   0   0     NaN  2007     reg           0          NaN
# 215   0   0   0     NaN  2007     reg           0          NaN
# 224   0   0   0     NaN  2007     reg           0          NaN
# 227   0   0   0     NaN  2007     reg           0          NaN
# 229   0   0   0     NaN  2007     reg           0          NaN
# 234   0   0   0     NaN  2007     reg           0          NaN
# 238   0   0   0     NaN  2007     reg           1          NaN
# 241   0   0   0     NaN  2007     reg           1          NaN
#
#      Base Guaranteed Comp.
# 6                      NaN
# 7                      NaN
# 9                      NaN
# 10                     NaN
# 27                     NaN
# 45                     NaN
# 65                     NaN
# 83                     NaN
# 109                    NaN
# 116                    NaN
# 129                    NaN
# 136                    NaN
# 146                    NaN
# 170                    NaN
# 173                    NaN
# 175                    NaN
# 176                    NaN
# 189                    NaN
# 194                    NaN
# 205                    NaN
# 206                    NaN
# 207                    NaN
# 214                    NaN
# 215                    NaN
# 224                    NaN
# 227                    NaN
# 229                    NaN
# 234                    NaN
# 238                    NaN
# 241                    NaN
#
# [30 rows x 31 columns]

# %%
# Dropping all rows with player names in bad fuzz df
for i, player in player_stats_salaries_df.iterrows():
    if player['Player'] in bad_fuzz['Fuzz Name'].values:
        player_stats_salaries_df.drop(i, inplace=True)

# %%
player_stats_salaries_df.isna().sum()
# Out:
# Player                      0
# Club                        0
# POS                         0
# GP                          0
# GS                          0
# MINS                        0
# G                           0
# A                           0
# SHTS                        0
# SOG                         0
# GWG                         0
# PKG/A                       0
# HmG                         0
# RdG                         0
# G/90min                     0
# SC%                         0
# GWA                         0
# HmA                         0
# RdA                         0
# A/90min                     0
# FC                          0
# FS                          0
# OFF                         0
# YC                          0
# RC                          0
# SOG%                     1415
# Year                        0
# Season                      0
# Postseason                  0
# Base Salary               728
# Base Guaranteed Comp.     728
# dtype: int64

# %%
player_stats_salaries_df[player_stats_salaries_df['Base Salary'].isna()]
# Out:
#                 Player Club POS  GP  GS  MINS   G  A  SHTS  SOG  ...  FS OFF  \
# 6      christian gomez  DC    M  27  27  2272  10  9    82   44  ...  43  10
# 7        jozy altidore  TOR   F  22  15  1399   9  4    43   20  ...  43  12
# 9       robbie findley  LA    F  25  14  1353   8  0    31   16  ...  27  14
# 10                fred  DC    M  26  23  2096   7  8    28   14  ...  40  21
# 27           juan toja  DAL   M  27  27  2388   6  1    33   16  ...  41   6
# ...                ...  ...  ..  ..  ..   ...  .. ..   ...  ...  ...  ..  ..
# 7154   wilfried zahibo  HOU   M   7   3   298   0  0     2    0  ...   3   1
# 7174     sam nicholson  COL   F   2   2   174   0  0     3    0  ...   3   2
# 7223  aleksandar katai   LA   M   2   2   117   0  0     8    0  ...   2   0
# 7236     boniek garcia  HOU   M  18   7   819   0  0    12    1  ...   9   0
# 7244     nicolas figal  MIA   D  21  21  1746   0  0    22    9  ...  26   0
#
#       YC  RC   SOG%  Year  Season  Postseason  Base Salary  \
# 6      6   0  53.66  2007     reg           1          NaN
# 7      4   0  46.51  2007     reg           1          NaN
# 9      0   0  51.61  2007     reg           0          NaN
# 10     5   1  50.00  2007     reg           1          NaN
# 27     4   0  48.48  2007     reg           1          NaN
# ...   ..  ..    ...   ...     ...         ...          ...
# 7154   2   0   0.00  2020     reg           0          NaN
# 7174   0   0   0.00  2020     reg           0          NaN
# 7223   2   0   0.00  2020     reg           0          NaN
# 7236   5   0   8.33  2020     reg           0          NaN
# 7244   4   0  40.91  2020     reg           1          NaN
#
#       Base Guaranteed Comp.
# 6                       NaN
# 7                       NaN
# 9                       NaN
# 10                      NaN
# 27                      NaN
# ...                     ...
# 7154                    NaN
# 7174                    NaN
# 7223                    NaN
# 7236                    NaN
# 7244                    NaN
#
# [728 rows x 31 columns]

# %%
# Drop all rows where Base Salary is null
player_stats_salaries_df.dropna(subset='Base Salary',inplace = True)

# %%
player_stats_salaries_df.isna().sum()
# Out:
# Player                      0
# Club                        0
# POS                         0
# GP                          0
# GS                          0
# MINS                        0
# G                           0
# A                           0
# SHTS                        0
# SOG                         0
# GWG                         0
# PKG/A                       0
# HmG                         0
# RdG                         0
# G/90min                     0
# SC%                         0
# GWA                         0
# HmA                         0
# RdA                         0
# A/90min                     0
# FC                          0
# FS                          0
# OFF                         0
# YC                          0
# RC                          0
# SOG%                     1136
# Year                        0
# Season                      0
# Postseason                  0
# Base Salary                 0
# Base Guaranteed Comp.       0
# dtype: int64

# %%
player_stats_salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6161 entries, 0 to 7243
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Player                 6161 non-null   object
#  1   Club                   6161 non-null   object
#  2   POS                    6161 non-null   object
#  3   GP                     6161 non-null   int64
#  4   GS                     6161 non-null   int64
#  5   MINS                   6161 non-null   int64
#  6   G                      6161 non-null   int64
#  7   A                      6161 non-null   int64
#  8   SHTS                   6161 non-null   int64
#  9   SOG                    6161 non-null   int64
#  10  GWG                    6161 non-null   int64
#  11  PKG/A                  6161 non-null   object
#  12  HmG                    6161 non-null   int64
#  13  RdG                    6161 non-null   int64
#  14  G/90min                6161 non-null   float64
#  15  SC%                    6161 non-null   float64
#  16  GWA                    6161 non-null   int64
#  17  HmA                    6161 non-null   int64
#  18  RdA                    6161 non-null   int64
#  19  A/90min                6161 non-null   float64
#  20  FC                     6161 non-null   int64
#  21  FS                     6161 non-null   int64
#  22  OFF                    6161 non-null   int64
#  23  YC                     6161 non-null   int64
#  24  RC                     6161 non-null   int64
#  25  SOG%                   5025 non-null   float64
#  26  Year                   6161 non-null   int64
#  27  Season                 6161 non-null   object
#  28  Postseason             6161 non-null   int64
#  29  Base Salary            6161 non-null   object
#  30  Base Guaranteed Comp.  6161 non-null   object
# dtypes: float64(4), int64(20), object(7)
# memory usage: 1.5+ MB

# %%
keeper_stats_salaries_df.isna().sum()
# Out:
# Player                     0
# Club                       0
# POS                        0
# GP                         0
# GS                         0
# MINS                       0
# SHTS                       0
# SV                         0
# GA                         0
# GAA                        0
# PKG/A                      0
# W                          0
# L                          0
# T                          0
# ShO                        0
# W%                         0
# Sv%                        0
# Year                       0
# Season                     0
# Postseason                 0
# Base Salary              107
# Base Guaranteed Comp.    107
# dtype: int64

# %%
#Drop all rows where Base salary is null
keeper_stats_salaries_df.dropna(subset='Base Salary', inplace=True)

# %%
#convert to csv 
#player_stats_salaries_df.to_csv('./data/player_stats_salaries.csv')
#keeper_stats_salaries_df.to_csv('./data/keeper_stats_salaries.csv')

# %%
# remove Unnamed column and reset index
player_stats_salaries_df.drop(columns='Unnamed: 0', inplace=True)
player_stats_salaries_df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 2
#       1 # remove Unnamed column and reset index
# ----> 2 player_stats_salaries_df.drop(columns='Unnamed: 0', inplace=True)
#       3 player_stats_salaries_df.reset_index(inplace=True)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
for i in range(len(player_stats_salaries_df)):
    pos = player_stats_salaries_df.at[i, 'POS']
    if pos == 'M-F':
        player_stats_salaries_df.at[i, 'POS'] = 'M'
    elif pos == 'D-M':
        player_stats_salaries_df.at[i, 'POS'] = 'D'
    elif pos == 'F-M':
        player_stats_salaries_df.at[i, 'POS'] = 'F'
    elif pos == 'M-D':
        player_stats_salaries_df.at[i, 'POS'] = 'M'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'POS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[114], line 2
#       1 for i in range(len(player_stats_salaries_df)):
# ----> 2     pos = player_stats_salaries_df.at[i, 'POS']
#       3     if pos == 'M-F':
#       4         player_stats_salaries_df.at[i, 'POS'] = 'M'
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexing.py:2488, in _AtIndexer.__getitem__(self, key)
#    2485         raise ValueError("Invalid call for scalar access (getting)!")
#    2486     return self.obj.loc[key]
# -> 2488 return super().__getitem__(key)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexing.py:2440, in _ScalarAccessIndexer.__getitem__(self, key)
#    2437         raise ValueError("Invalid call for scalar access (getting)!")
#    2439 key = self._convert_key(key)
# -> 2440 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/frame.py:4008, in DataFrame._get_value(self, index, col, takeable)
#    4005     series = self._ixs(col, axis=1)
#    4006     return series._values[index]
# -> 4008 series = self._get_item_cache(col)
#    4009 engine = self.index._engine
#    4011 if not isinstance(self.index, MultiIndex):
#    4012     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4013     #  results if our categories are integers that dont match our codes
#    4014     # IntervalIndex: IntervalTree has no get_loc
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/frame.py:4417, in DataFrame._get_item_cache(self, item)
#    4412 res = cache.get(item)
#    4413 if res is None:
#    4414     # All places that call _get_item_cache have unique columns,
#    4415     #  pending resolution of GH#33047
# -> 4417     loc = self.columns.get_loc(item)
#    4418     res = self._ixs(loc, axis=1)
#    4420     cache[item] = res
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'POS'

# %%
one_hot = pd.get_dummies(player_stats_salaries_df['POS'])
one_hot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'POS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 one_hot = pd.get_dummies(player_stats_salaries_df['POS'])
#       2 one_hot
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'POS'

# %%
one_hot['D'] = one_hot['D'].astype(int)
one_hot['F'] = one_hot['F'].astype(int)
one_hot['M'] = one_hot['M'].astype(int)
one_hot
# Out:
#       D    D-M  F    F-M  M    M-D    M-F
# 0     0  False  1  False  0  False  False
# 1     0  False  1  False  0  False  False
# 2     0  False  1  False  0  False  False
# 4     0  False  1  False  0  False  False
# 5     0  False  1  False  0  False  False
# ...  ..    ... ..    ... ..    ...    ...
# 7237  1  False  0  False  0  False  False
# 7238  0  False  0  False  1  False  False
# 7239  0  False  0  False  1  False  False
# 7241  0  False  0  False  1  False  False
# 7243  1  False  0  False  0  False  False
#
# [6161 rows x 7 columns]

# %%
player_stats_salaries_df['Defender'] = one_hot['D']
player_stats_salaries_df['Forward'] = one_hot['F']
player_stats_salaries_df['Midfielder'] = one_hot['M']
player_stats_salaries_df.drop(columns='POS', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 4
#       2 player_stats_salaries_df['Forward'] = one_hot['F']
#       3 player_stats_salaries_df['Midfielder'] = one_hot['M']
# ----> 4 player_stats_salaries_df.drop(columns='POS', inplace=True)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['POS'] not found in axis"

# %%
player_stats_salaries_df
# Out:
#                 Player Club  GP  GS  MINS   G  A  SHTS  SOG  GWG  ...   SOG%  \
# 0       luciano emilio  DC   29  28  2410  20  1    79   47    4  ...  59.49
# 1     juan pablo angel  NY   24  24  2125  19  5    97   53    5  ...  54.64
# 2      taylor twellman  NE   26  25  2283  16  3    90   55    5  ...  61.11
# 4       maykel galindo  CHV  28  24  2021  12  5    55   28    5  ...  50.91
# 5           ante razov  CHV  26  24  2041  11  8    85   42    4  ...  49.41
# ...                ...  ...  ..  ..   ...  .. ..   ...  ...  ...  ...    ...
# 7237      nedum onuoha  RSL  15  15  1318   0  0    12    2    0  ...  16.67
# 7238    sacha kljestan   LA  15   8   769   0  0    13    4    0  ...  30.77
# 7239            judson   SJ  21  20  1701   0  0    14    1    0  ...   7.14
# 7241        kelyn rowe   NE  16  10   896   0  0    17    4    0  ...  23.53
# 7243     maxime chanot  NYC  20  20  1712   0  0    19    4    0  ...  21.05
#
#       Year  Season  Postseason  Base Salary  Base Guaranteed Comp.  Defender  \
# 0     2007     reg           1       265000                 293125         0
# 1     2007     reg           1      1500000                1593750         0
# 2     2007     reg           1       325008                 350008         0
# 4     2007     reg           1        72500                  72500         0
# 5     2007     reg           1       245000                 248750         0
# ...    ...     ...         ...          ...                    ...       ...
# 7237  2020     reg           0       549996                 603996         1
# 7238  2020     reg           0       307000                 307000         0
# 7239  2020     reg           1       320000                 325000         0
# 7241  2020     reg           1       310610                 310610         0
# 7243  2020     reg           1       725000                 725000         1
#
#       Forward  Midfielder  Minimum_Salary
# 0           1           0           30000
# 1           1           0           30000
# 2           1           0           30000
# 4           1           0           30000
# 5           1           0           30000
# ...       ...         ...             ...
# 7237        0           0           81375
# 7238        0           1           81375
# 7239        0           1           81375
# 7241        0           1           81375
# 7243        0           0           81375
#
# [6161 rows x 34 columns]

# %%
minimum_salary = {2007: 30000, 2008: 33000, 2009: 34000, 2010: 40000, 2011: 42000, 2012: 45000, 2013: 46500,
                  2014: 48500, 2015: 60000, 2016: 62500, 2017: 65000, 2018: 67500, 2019: 70250, 2020: 81375}

player_stats_salaries_df['Minimum_Salary'] = player_stats_salaries_df['Year'].apply(lambda year: minimum_salary.get(year, 0))

# %%
player_stats_salaries_df[player_stats_salaries_df['Base Salary'] < player_stats_salaries_df['Minimum_Salary']]
# Out:
#                    Player Club  GP  GS  MINS  G  A  SHTS  SOG  GWG  ...  \
# 42          adam cristman  NE   28  14  1421  4  4    40   16    0  ...
# 85            colin clark  COL  16  16  1321  2  2    26    5    0  ...
# 90             kyle brown  RSL   8   3   286  2  0     7    4    1  ...
# 127           jeff curtin  CHI   3   3   248  1  0     2    1    0  ...
# 131          floyd franks  CHI   7   2   223  1  0     3    1    0  ...
# ...                   ...  ...  ..  ..   ... .. ..   ...  ...  ...  ...
# 7182     tah brian anunga  NSH  14   8   779  0  0     3    0    0  ...
# 7184         kamal miller  ORL  12   9   805  0  0     3    0    0  ...
# 7194            alan winn  NSH   7   1   239  0  0     4    1    0  ...
# 7195        laurence wyke  ATL   7   2   226  0  0     4    1    0  ...
# 7208  sebastian berhalter  CLB   9   4   395  0  0     6    0    0  ...
#
#        SOG%  Year  Season  Postseason  Base Salary  Base Guaranteed Comp.  \
# 42    40.00  2007     reg           1        17700                  17700
# 85    19.23  2007     reg           0        17700                  17700
# 90    57.14  2007     reg           0        17700                  17700
# 127   50.00  2007     reg           1        12900                  12900
# 131   33.33  2007     reg           1        17700                  17700
# ...     ...   ...     ...         ...          ...                    ...
# 7182   0.00  2020     reg           1        63547                  63547
# 7184   0.00  2020     reg           1        63547                  63547
# 7194  25.00  2020     reg           1        63547                  63547
# 7195  25.00  2020     reg           0        63547                  63547
# 7208   0.00  2020     reg           1        75000                  76250
#
#       Defender  Forward  Midfielder  Minimum_Salary
# 42           0        1           0           30000
# 85           0        0           1           30000
# 90           0        1           0           30000
# 127          1        0           0           30000
# 131          0        0           1           30000
# ...        ...      ...         ...             ...
# 7182         0        0           1           81375
# 7184         1        0           0           81375
# 7194         0        1           0           81375
# 7195         1        0           0           81375
# 7208         0        0           1           81375
#
# [794 rows x 34 columns]

# %%
for i, salary in player_stats_salaries_df.iterrows():
    if player_stats_salaries_df.at[i, 'Base Salary'] < player_stats_salaries_df.at[i, 'Minimum_Salary']:
        player_stats_salaries_df.drop(i, inplace=True)

# %%
player_stats_salaries_df
# Out:
#                 Player Club  GP  GS  MINS   G  A  SHTS  SOG  GWG  ...   SOG%  \
# 0       luciano emilio  DC   29  28  2410  20  1    79   47    4  ...  59.49
# 1     juan pablo angel  NY   24  24  2125  19  5    97   53    5  ...  54.64
# 2      taylor twellman  NE   26  25  2283  16  3    90   55    5  ...  61.11
# 4       maykel galindo  CHV  28  24  2021  12  5    55   28    5  ...  50.91
# 5           ante razov  CHV  26  24  2041  11  8    85   42    4  ...  49.41
# ...                ...  ...  ..  ..   ...  .. ..   ...  ...  ...  ...    ...
# 7237      nedum onuoha  RSL  15  15  1318   0  0    12    2    0  ...  16.67
# 7238    sacha kljestan   LA  15   8   769   0  0    13    4    0  ...  30.77
# 7239            judson   SJ  21  20  1701   0  0    14    1    0  ...   7.14
# 7241        kelyn rowe   NE  16  10   896   0  0    17    4    0  ...  23.53
# 7243     maxime chanot  NYC  20  20  1712   0  0    19    4    0  ...  21.05
#
#       Year  Season  Postseason  Base Salary  Base Guaranteed Comp.  Defender  \
# 0     2007     reg           1       265000                 293125         0
# 1     2007     reg           1      1500000                1593750         0
# 2     2007     reg           1       325008                 350008         0
# 4     2007     reg           1        72500                  72500         0
# 5     2007     reg           1       245000                 248750         0
# ...    ...     ...         ...          ...                    ...       ...
# 7237  2020     reg           0       549996                 603996         1
# 7238  2020     reg           0       307000                 307000         0
# 7239  2020     reg           1       320000                 325000         0
# 7241  2020     reg           1       310610                 310610         0
# 7243  2020     reg           1       725000                 725000         1
#
#       Forward  Midfielder  Minimum_Salary
# 0           1           0           30000
# 1           1           0           30000
# 2           1           0           30000
# 4           1           0           30000
# 5           1           0           30000
# ...       ...         ...             ...
# 7237        0           0           81375
# 7238        0           1           81375
# 7239        0           1           81375
# 7241        0           1           81375
# 7243        0           0           81375
#
# [5367 rows x 34 columns]

# %%
player_stats_salaries_df.rename(columns={'PKG/A': 'Penalty_Kick_Conversion_Rate', 'G/90min': 'Goals_per_90_Minutes', 
                                          'A/90min': 'Assists_per_90_Minutes', 'GP': 'Games_Played',
                                         'GS': 'Games_Started', 'MINS': 'Total_Minutes_Played', 'G': 'Goals',
                                         'A': 'Assists', 'SHTS': 'Shots', 'SOG': 'Shots_On_Goal', 
                                        'GWG': 'Game_Winning_Goals', 'HmG': 'Home_Goals', 'RdG': 'Road_Goals',
                                        'SC%': 'Shots_Conversion', 'GWA': 'Game_Winning_Assists',
                                        'HmA': 'Home_Assists', 'RdA': 'Road_Assists', 'FC': 'Fouls_Committed',
                                        'FS': 'Fouls_Suffered', 'OFF': 'Offsides', 'YC': 'Yellow_Cards',
                                        'RC': 'Red_Cards', 'SOG%': 'Shots_On_Goal_Rate'}, inplace=True)

# %%
player_stats_salaries_df['Penalty_Kick_Conversion_Rate']
# Out:
# 0       0/0
# 1       5/5
# 2       0/0
# 4       0/0
# 5       1/1
#        ...
# 7237    0/0
# 7238    0/0
# 7239    0/0
# 7241    0/0
# 7243    0/0
# Name: Penalty_Kick_Conversion_Rate, Length: 5367, dtype: object

# %%
player_stats_salaries_df = player_stats_salaries_df[player_stats_salaries_df['Total_Minutes_Played'] != 0]

# %%
player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'] = player_stats_salaries_df["Penalty_Kicks_Scored"].astype(float) / player_stats_salaries_df["Penalty_Kicks_Taken"].astype(float)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].fillna(value=0, inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/132888053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/132888053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/132888053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Penalty_Kick_Conversion_Rate'] = player_stats_salaries_df["Penalty_Kicks_Scored"].astype(float) / player_stats_salaries_df["Penalty_Kicks_Taken"].astype(float)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/132888053.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].fillna(value=0, inplace=True)

# %%
player_stats_salaries_df['Shots_On_Goal_Rate'].fillna(value=0, inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/825700931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Shots_On_Goal_Rate'].fillna(value=0, inplace=True)

# %%
salary_cap = {2007: 2100000, 2008: 2300000, 2009: 2300000, 2010: 2550000, 2011: 2670000, 2012: 2810000, 2013: 2950000, 2014: 3100000, 2015: 3490000, 2016: 3660000, 2017: 3845000,
              2018: 4035000, 2019: 4240000, 2020: 4900000}
player_stats_salaries_df['Salary Cap'] = player_stats_salaries_df['Year'].apply(lambda year: salary_cap.get(year, 0))
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/1585667694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Salary Cap'] = player_stats_salaries_df['Year'].apply(lambda year: salary_cap.get(year, 0))

# %%
player_stats_salaries_df['Bonus Pay'] = player_stats_salaries_df['Base Guaranteed Comp.'] - player_stats_salaries_df['Base Salary']
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_49794/1575893766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Bonus Pay'] = player_stats_salaries_df['Base Guaranteed Comp.'] - player_stats_salaries_df['Base Salary']

# %%
stats_salaries_df = player_stats_salaries_df.drop(columns=['Player', 'Club', 'Season', 'Base Guaranteed Comp.'
                                                           ])

# %%
stats_salaries_df
# Out:
#       Games_Played  Games_Started  Total_Minutes_Played  Goals  Assists  \
# 0               29             28                  2410     20        1
# 1               24             24                  2125     19        5
# 2               26             25                  2283     16        3
# 4               28             24                  2021     12        5
# 5               26             24                  2041     11        8
# ...            ...            ...                   ...    ...      ...
# 7237            15             15                  1318      0        0
# 7238            15              8                   769      0        0
# 7239            21             20                  1701      0        0
# 7241            16             10                   896      0        0
# 7243            20             20                  1712      0        0
#
#       Shots  Shots_On_Goal  Game_Winning_Goals  Penalty_Kick_Conversion_Rate  \
# 0        79             47                   4                           0.0
# 1        97             53                   5                           1.0
# 2        90             55                   5                           0.0
# 4        55             28                   5                           0.0
# 5        85             42                   4                           1.0
# ...     ...            ...                 ...                           ...
# 7237     12              2                   0                           0.0
# 7238     13              4                   0                           0.0
# 7239     14              1                   0                           0.0
# 7241     17              4                   0                           0.0
# 7243     19              4                   0                           0.0
#
#       Home_Goals  ...  Postseason  Base Salary  Defender  Forward  Midfielder  \
# 0             12  ...           1       265000         0        1           0
# 1             13  ...           1      1500000         0        1           0
# 2              7  ...           1       325008         0        1           0
# 4              8  ...           1        72500         0        1           0
# 5              9  ...           1       245000         0        1           0
# ...          ...  ...         ...          ...       ...      ...         ...
# 7237           0  ...           0       549996         1        0           0
# 7238           0  ...           0       307000         0        0           1
# 7239           0  ...           1       320000         0        0           1
# 7241           0  ...           1       310610         0        0           1
# 7243           0  ...           1       725000         1        0           0
#
#       Minimum_Salary  Penalty_Kicks_Scored  Penalty_Kicks_Taken  Salary Cap  \
# 0              30000                     0                    0     2100000
# 1              30000                     5                    5     2100000
# 2              30000                     0                    0     2100000
# 4              30000                     0                    0     2100000
# 5              30000                     1                    1     2100000
# ...              ...                   ...                  ...         ...
# 7237           81375                     0                    0     4900000
# 7238           81375                     0                    0     4900000
# 7239           81375                     0                    0     4900000
# 7241           81375                     0                    0     4900000
# 7243           81375                     0                    0     4900000
#
#       Bonus Pay
# 0         28125
# 1         93750
# 2         25000
# 4             0
# 5          3750
# ...         ...
# 7237      54000
# 7238          0
# 7239       5000
# 7241          0
# 7243          0
#
# [5025 rows x 34 columns]

# %%
stats_salaries_df['Penalty_Kicks_Scored'] = stats_salaries_df['Penalty_Kicks_Scored'].astype(int)
stats_salaries_df["Penalty_Kicks_Taken"]= stats_salaries_df['Penalty_Kicks_Taken'].astype(int)

# %%
sns.set(rc={'figure.figsize': (10, 10)})

sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
X = stats_salaries_df.drop(columns='Base Salary')
y = stats_salaries_df['Base Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

dummy_mse = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_squared_error'))
dummy_mse
# Out:
# -402280238977.02185

# %%
dummy_rmse = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_root_mean_squared_error'))
dummy_rmse
# Out:
# -633590.1940370485

# %%
dummy_mae = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_absolute_error'))
dummy_mae
# Out:
# -286589.1683311273

# %%
y_pred = dummy.predict(X_train)

dummy_score = r2_score(y_train, y_pred)
dummy_score
# Out:
# 0.0

# %%
lr = LinearRegression()
scaler = StandardScaler()
X_train_sc= scaler.fit_transform(X_train)
X_test_sc= scaler.transform(X_test)

lr.fit(X_train_sc, y_train)
y_pred = lr.predict(X_train_sc)

# %%
plt.scatter(y_train, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
lr_mse = np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
lr_mse
# Out:
# -315603003779.3019

# %%
rmse = np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_root_mean_squared_error'))
rmse
# Out:
# -545250.7435302286

# %%
lr_mae =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
lr_mae
# Out:
# -219137.7659976477

# %%
y_pred_lr = lr.predict(X_train_sc)

lr_score =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'r2'))
lr_score
# Out:
# 0.2363902261574562

# %%
pipe = Pipeline([
    ('pca', PCA(random_state=42)),
    ('lr', LinearRegression())
])

# %%
param_grid = {
    'pca__n_components': [23, 24, 25],
    'pca__copy': [False, True],
    'pca__whiten': [False, True]
}

# %%
grid = GridSearchCV(pipe, param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
grid.fit(X_train_sc, y_train)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 0.2306529575451283
# {'pca__copy': False, 'pca__n_components': 23, 'pca__whiten': False}

# %%
rf = RandomForestRegressor(random_state=42)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_score = np.mean(cross_val_score(rf, X_train, y_train, cv=5))
rf_score
# Out:
# 0.511960558678069

# %%
rf_mse = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
rf_mse
# Out:
# -192162046276.4961

# %%
rf_rmse = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_root_mean_squared_error'))
rf_rmse
# Out:
# -436081.43653891457

# %%
rf_mae = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
rf_mae
# Out:
# -173803.11930165422

# %%
rfpipe = Pipeline([('pca', PCA(random_state=42)),
                    ('rf', RandomForestRegressor(random_state=42))])

# %%
rf_param_grid = {
    'pca__n_components': [10, 20, 30],
    'rf__n_estimators': [10, 50, 100],
    'rf__min_samples_split': [2, 5, 10],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0.5345565395473595
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 5, 'rf__n_estimators': 100}

# %%
rf_param_grid = {
    'pca__n_components': [30, 50, 70],
    'rf__n_estimators': [75, 125, 175],
    'rf__min_samples_split': [3, 5, 7],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.9s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   4.4s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.9s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.1s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   9.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   9.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  13.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  14.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  14.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  11.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  25.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  19.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  24.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.7s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 270 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=50 must be between 0 and min(n_samples, n_features)=33 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=70 must be between 0 and min(n_samples, n_features)=33 with svd_solver='full'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.51343223 0.50906365 0.51121964 0.51228658 0.51006487 0.51089934
#  0.51788264 0.51217988 0.51233027 0.51204797 0.50947234 0.51059212
#  0.51217294 0.50935792 0.51060834 0.5185132  0.51232027 0.5130118
#  0.53171022 0.53361164 0.53564463 0.53306154 0.53299309 0.53446062
#  0.53126227 0.53035226 0.53340579        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the train scores are non-finite: [0.92736888 0.92983175 0.93004493 0.90845876 0.91026767 0.9111998
#  0.88909625 0.89105142 0.89168702 0.92674648 0.92951203 0.92971206
#  0.90853209 0.91037647 0.91126745 0.88908158 0.89115146 0.89173083
#  0.92974254 0.9314104  0.93139713 0.91199696 0.91326291 0.91323556
#  0.88931536 0.89121873 0.89155916        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# 0.535644633537389
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 3, 'rf__n_estimators': 175}

# %%
rf_param_grid = {
    'pca__n_components': [25, 30, 32],
    'rf__n_estimators': [145, 160, 175],
    'rf__min_samples_split': [4, 5, 6],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0.5363341935789645
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 4, 'rf__n_estimators': 160}

# %%
pca = PCA()
pca.fit(X_train_sc, y_train)

knn = KNeighborsRegressor()
knn.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_k = knn.predict(X_train_sc)
y_pred_k
# Out:
# array([610051.6240000001, 182148.408, 311800.00800000003, ..., 127700.008,
#        182790.0, 82519.39199999999], dtype=object)

# %%
knn_train = knn.score(X_train_sc, y_train)
knn_val = knn.score(X_test_sc, y_test)
print(knn_train)
print(knn_val)
# Out:
# 0.5941649586365371
# 0.1871902011658888

# %%
plt.scatter(y_train, y_pred_k)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
X_test= np.linspace(X_train_sc.min(), X_train_sc.max(), 500)[:, np.newaxis]

# %%
plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
plt.plot(X_train_sc, X_test, color='blue', label='True Values')
plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
plt.xlabel('X')
plt.ylabel('y')
plt.title('KNeighborsRegressor')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
#       2 plt.plot(X_train_sc, X_test, color='blue', label='True Values')
#       3 plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4652, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4650 y = np.ma.ravel(y)
#    4651 if x.size != y.size:
# -> 4652     raise ValueError("x and y must be the same size")
#    4654 if s is None:
#    4655     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4656          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
knn_mse = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5, scoring = 'neg_mean_squared_error'))
knn_mse

# %%
knn_rmse = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5, scoring = 'neg_root_mean_squared_error'))
knn_rmse
# Out:
# -516404.4783039514

# %%
knn_mae = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
knn_mae
# Out:
# -214122.4845955397

# %%
knn_mae = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
knn_mae
# Out:
# -214122.4845955397

# %%
kpipe = Pipeline([('pca', PCA(random_state=42)),
                  ('knn', KNeighborsRegressor())
                 ])

# %%
k_param_grid = {
    'pca__n_components': [5, 10, 15],
    'knn__n_neighbors': [3, 5, 7],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# 0.37793129879855963
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 7, 'knn__weights': 'distance', 'pca__n_components': 5}

# %%
k_param_grid = {
    'pca__n_components': [7, 10, 13],
    'knn__n_neighbors': [7, 15, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# 0.38320577859055704
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 15, 'knn__weights': 'distance', 'pca__n_components': 10}

# %%
k_param_grid = {
    'pca__n_components': [3, 5, 7],
    'knn__n_neighbors': [17, 20, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=5, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# 0.4199252580475563
# {'knn__metric': 'minkowski', 'knn__n_neighbors': 17, 'knn__weights': 'distance', 'pca__n_components': 5}

# %%
knn_score= np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5))
knn_score
# Out:
# 0.3215565984299893
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.2s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   3.8s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   9.8s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   4.5s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   4.5s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  14.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  13.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  13.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  14.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  11.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   9.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  23.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=  17.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  18.1s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.2s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  20.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  19.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  25.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  23.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  25.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  22.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  22.9s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.2s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  25.3s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  21.2s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  23.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  23.0s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.2s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.9s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.2s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=distance, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=distance, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=distance, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=distance, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=distance, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.1s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.6s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.1s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.2s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  10.0s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   9.6s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   8.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  14.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   6.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=  25.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=  17.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  23.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  20.1s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  20.8s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  18.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  20.7s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.0s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  23.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  24.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  23.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  23.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  23.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  21.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  22.5s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.9s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.8s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  21.3s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  21.4s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.4s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.1s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.4s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.3s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=distance, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=13; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.8s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.1s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   9.6s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   8.8s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   9.5s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  10.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  15.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  13.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  13.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=  17.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=  17.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  26.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  24.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=  16.8s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.1s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  18.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  21.7s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  20.0s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  16.4s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  20.5s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  15.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  19.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  25.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  21.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  19.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.0s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  21.4s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.9s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.3s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.1s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  21.5s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.9s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  19.2s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.1s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.7s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.6s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.8s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   9.8s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   8.6s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   9.9s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   8.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  13.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  13.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=  25.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=  24.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   9.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  16.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=  18.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  16.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  16.7s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.4s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.4s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.9s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  18.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  25.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  26.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  24.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  22.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  22.5s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  25.5s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.0s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.9s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.5s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.8s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  25.0s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.7s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.5s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# ...
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=17, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.6s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.0s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.8s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   4.8s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   9.5s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  10.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   9.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  14.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  15.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   6.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=  26.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  24.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  17.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=  15.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  16.8s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  16.0s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.0s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  18.4s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  26.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  25.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  21.1s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  23.6s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  22.4s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.5s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  26.1s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.3s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  20.2s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.5s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=3, knn__weights=distance, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=15; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=3, knn__weights=uniform, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=5, knn__weights=distance, pca__n_components=15; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=7, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=7, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance, pca__n_components=10; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=15, knn__weights=distance, pca__n_components=10; total time=   0.1s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=13; total time=   0.1s
# [CV] END knn__metric=minkowski, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=minkowski, knn__n_neighbors=23, knn__weights=uniform, pca__n_components=5; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=uniform, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=17, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=euclidean, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=20, knn__weights=uniform, pca__n_components=7; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=3; total time=   0.0s
# [CV] END knn__metric=manhattan, knn__n_neighbors=23, knn__weights=distance, pca__n_components=7; total time=   0.1s
