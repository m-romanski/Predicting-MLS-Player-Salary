# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.datasets import make_blobs
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import r2_score, silhouette_score, mean_squared_error, mean_absolute_error 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor

# %%
# create dataframes of csv
player_stats_salaries_df = pd.read_csv('./data/player_stats_salaries.csv')

# %%
#New index was created
player_stats_salaries_df.head()
# Out:
#    Unnamed: 0            Player Club POS  GP  GS  MINS   G  A  SHTS  ...  FC  \
# 0           0    luciano emilio  DC    F  29  28  2410  20  1    79  ...  35
# 1           1  juan pablo angel  NY    F  24  24  2125  19  5    97  ...  31
# 2           2   taylor twellman  NE    F  26  25  2283  16  3    90  ...  13
# 3           4    maykel galindo  CHV   F  28  24  2021  12  5    55  ...  44
# 4           5        ante razov  CHV   F  26  24  2041  11  8    85  ...  37
#
#    FS OFF  YC  RC   SOG%  Year  Season  Base Salary  Base Guaranteed Comp.
# 0  39  21   2   0  59.49  2007     reg     265000.0               293125.0
# 1  20  42   2   1  54.64  2007     reg    1500000.0              1593750.0
# 2  41  21   2   0  61.11  2007     reg     325008.0               350008.0
# 3  53  30   6   0  50.91  2007     reg      72500.0                72500.0
# 4  33  30   2   0  49.41  2007     reg     245000.0               248750.0
#
# [5 rows x 31 columns]

# %%
# remove Unnamed column
player_stats_salaries_df.drop(columns='Unnamed: 0', inplace=True)

# %%
player_stats_salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6161 entries, 0 to 6160
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Player                 6161 non-null   object
#  1   Club                   6161 non-null   object
#  2   POS                    6161 non-null   object
#  3   GP                     6161 non-null   int64
#  4   GS                     6161 non-null   int64
#  5   MINS                   6161 non-null   int64
#  6   G                      6161 non-null   int64
#  7   A                      6161 non-null   int64
#  8   SHTS                   6161 non-null   int64
#  9   SOG                    6161 non-null   int64
#  10  GWG                    6161 non-null   int64
#  11  PKG/A                  6161 non-null   object
#  12  HmG                    6161 non-null   int64
#  13  RdG                    6161 non-null   int64
#  14  G/90min                6161 non-null   float64
#  15  SC%                    6161 non-null   float64
#  16  GWA                    6161 non-null   int64
#  17  HmA                    6161 non-null   int64
#  18  RdA                    6161 non-null   int64
#  19  A/90min                6161 non-null   float64
#  20  FC                     6161 non-null   int64
#  21  FS                     6161 non-null   int64
#  22  OFF                    6161 non-null   int64
#  23  YC                     6161 non-null   int64
#  24  RC                     6161 non-null   int64
#  25  SOG%                   5025 non-null   float64
#  26  Year                   6161 non-null   int64
#  27  Season                 6161 non-null   object
#  28  Base Salary            6161 non-null   float64
#  29  Base Guaranteed Comp.  6161 non-null   float64
# dtypes: float64(6), int64(19), object(5)
# memory usage: 1.4+ MB

# %%
for i in range(len(player_stats_salaries_df)):
    pos = player_stats_salaries_df.at[i, 'POS']
    if pos == 'M-F':
        player_stats_salaries_df.at[i, 'POS'] = 'M'
    elif pos == 'D-M':
        player_stats_salaries_df.at[i, 'POS'] = 'D'
    elif pos == 'F-M':
        player_stats_salaries_df.at[i, 'POS'] = 'F'
    elif pos == 'M-D':
        player_stats_salaries_df.at[i, 'POS'] = 'M'

# %%
one_hot = pd.get_dummies(player_stats_salaries_df['POS'])
one_hot
# Out:
#           D      F      M
# 0     False   True  False
# 1     False   True  False
# 2     False   True  False
# 3     False   True  False
# 4     False   True  False
# ...     ...    ...    ...
# 6156   True  False  False
# 6157  False  False   True
# 6158  False  False   True
# 6159  False  False   True
# 6160   True  False  False
#
# [6161 rows x 3 columns]

# %%
one_hot['D'] = one_hot['D'].astype(int)
one_hot['F'] = one_hot['F'].astype(int)
one_hot['M'] = one_hot['M'].astype(int)
one_hot
# Out:
#       D  F  M
# 0     0  1  0
# 1     0  1  0
# 2     0  1  0
# 3     0  1  0
# 4     0  1  0
# ...  .. .. ..
# 6156  1  0  0
# 6157  0  0  1
# 6158  0  0  1
# 6159  0  0  1
# 6160  1  0  0
#
# [6161 rows x 3 columns]

# %%
player_stats_salaries_df['Defender'] = one_hot['D']
player_stats_salaries_df['Forward'] = one_hot['F']
player_stats_salaries_df['Midfielder'] = one_hot['M']
player_stats_salaries_df.drop(columns='POS', inplace=True)
# Out:
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.7s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.7s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.2s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.6s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.2s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.3s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.3s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  11.2s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  15.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   8.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   8.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=  14.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  14.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=  25.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=  19.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  20.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=  19.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  26.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=  17.7s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=  20.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=  15.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=  19.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=  15.8s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=  19.9s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=  14.7s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=  14.7s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=  19.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=  18.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  21.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=  20.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=  19.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=  17.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=  23.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=  17.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=  17.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=  17.5s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__n_components=35, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.6s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.4s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  11.3s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   7.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   9.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  16.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  16.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  25.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  30.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  12.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  26.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=  19.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=  19.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=  19.8s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=  14.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=  19.6s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=  20.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=  15.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=  19.0s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.0s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=  16.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=  20.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  22.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=  20.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=  20.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=  23.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=  23.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=  23.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=  17.5s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=True; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.8s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.8s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.9s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.8s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  12.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.2s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.3s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.8s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  15.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  15.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   7.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   8.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   8.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  25.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=  20.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=  27.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=  11.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  26.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=  16.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=  15.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=  14.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=110; total time=  15.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=  16.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=  18.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=  16.7s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  16.7s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=  17.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=  27.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=  21.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=  18.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=  18.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=  18.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=  23.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=  17.2s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.7s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.6s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.6s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.9s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.4s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.7s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.9s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.2s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  15.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  18.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=  13.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=  33.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=  12.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=  26.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=  12.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  27.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=  15.9s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=  17.1s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  16.6s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=  18.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=  19.6s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=  20.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=125; total time=  16.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  16.7s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=125; total time=  17.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=  21.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  22.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=  20.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=  19.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  20.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=  23.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=  23.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=  22.3s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.2s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.2s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.6s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.7s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.3s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.8s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.8s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.6s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.9s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  15.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  15.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# ...
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  16.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  16.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=  14.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  13.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  15.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=  13.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=  19.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  28.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=  11.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  25.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=  11.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=  16.2s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=  17.7s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=  17.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=  16.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=  19.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=  19.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=  20.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  23.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=  21.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=  23.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=  24.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=  22.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=  17.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=  17.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=  14.5s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.6s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.6s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.6s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.7s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.8s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  11.1s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.3s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.8s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   7.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   8.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   8.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   8.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  25.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  29.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  12.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  28.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=  18.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=  15.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=  19.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=  19.7s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=  16.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=  15.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=140; total time=  20.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=110; total time=  14.9s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=  14.9s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=  19.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=110; total time=  18.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=110; total time=  17.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=140; total time=  26.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=110; total time=  17.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=110; total time=  18.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=  17.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=  21.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=  18.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=  14.2s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   4.9s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.5s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.6s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  11.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   7.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  14.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  16.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=  34.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=  12.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  12.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  19.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=  19.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  27.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  25.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=125; total time=  17.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.1s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=140; total time=  20.4s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=140; total time=  20.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=110; total time=  15.1s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=140; total time=  18.1s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=110; total time=  14.5s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=110; total time=  15.0s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=  19.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=140; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=125; total time=  22.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=125; total time=  21.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  21.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=125; total time=  20.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=140; total time=  22.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=140; total time=  22.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=140; total time=  14.7s

# %%
minimum_salary = {2007: 30000, 2008: 33000, 2009: 34000, 2010: 40000, 2011: 42000, 2012: 2810000, 2013: 2950000, 2014: 3100000, 2015: 3490000, 2016: 3660000, 2017: 3845000,
              2018: 4035000, 2019: 4240000, 2020: 4900000}

# %%
player_stats_salaries_df.rename(columns={'PKG/A': 'Penalty_Kick_Conversion_Rate', 'G/90min': 'Goals_per_90_Minutes', 
                                          'A/90min': 'Assists_per_90_Minutes', 'GP': 'Games_Played',
                                         'GS': 'Games_Started', 'MINS': 'Total_Minutes_Played', 'G': 'Goals',
                                         'A': 'Assists', 'SHTS': 'Shots', 'SOG': 'Shots_On_Goal', 
                                        'GWG': 'Game_Winning_Goals', 'HmG': 'Home_Goals', 'RdG': 'Road_Goals',
                                        'SC%': 'Shots_Conversion', 'GWA': 'Game_Winning_Assists',
                                        'HmA': 'Home_Assists', 'RdA': 'Road_Assists', 'FC': 'Fouls_Committed',
                                        'FS': 'Fouls_Suffered', 'OFF': 'Offsides', 'YC': 'Yellow_Cards',
                                        'RC': 'Red_Cards', 'SOG%': 'Shots_On_Goal_Rate'}, inplace=True)

# %%
player_stats_salaries_df['Penalty_Kick_Conversion_Rate']
# Out:
# 0       0/0
# 1       5/5
# 2       0/0
# 3       0/0
# 4       1/1
#        ...
# 6156    0/0
# 6157    0/0
# 6158    0/0
# 6159    0/0
# 6160    0/0
# Name: Penalty_Kick_Conversion_Rate, Length: 6161, dtype: object

# %%
player_stats_salaries_df = player_stats_salaries_df[player_stats_salaries_df['Total_Minutes_Played'] != 0]

# %%
player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'] = player_stats_salaries_df["Penalty_Kicks_Scored"].astype(float) / player_stats_salaries_df["Penalty_Kicks_Taken"].astype(float)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].fillna(value=0, inplace=True)

# %%
player_stats_salaries_df['Shots_On_Goal_Rate'].fillna(value=0, inplace=True)

# %%
salary_cap = {2007: 2100000, 2008: 2300000, 2009: 2300000, 2010: 2550000, 2011: 2670000, 2012: 2810000, 2013: 2950000, 2014: 3100000, 2015: 3490000, 2016: 3660000, 2017: 3845000,
              2018: 4035000, 2019: 4240000, 2020: 4900000}
player_stats_salaries_df['Salary Cap'] = player_stats_salaries_df['Year'].apply(lambda year: salary_cap.get(year, 0))

# %%
player_stats_salaries_df['Bonus Pay'] = player_stats_salaries_df['Base Guaranteed Comp.'] - player_stats_salaries_df['Base Salary']

# %%
stats_salaries_df = player_stats_salaries_df.drop(columns=['Player', 'Club', 'Season', 'Base Guaranteed Comp.'
                                                           ])

# %%
stats_salaries_df
# Out:
#       Games_Played  Games_Started  Total_Minutes_Played  Goals  Assists  \
# 0               29             28                  2410     20        1
# 1               24             24                  2125     19        5
# 2               26             25                  2283     16        3
# 3               28             24                  2021     12        5
# 4               26             24                  2041     11        8
# ...            ...            ...                   ...    ...      ...
# 6156            15             15                  1318      0        0
# 6157            15              8                   769      0        0
# 6158            21             20                  1701      0        0
# 6159            16             10                   896      0        0
# 6160            20             20                  1712      0        0
#
#       Shots  Shots_On_Goal  Game_Winning_Goals  Penalty_Kick_Conversion_Rate  \
# 0        79             47                   4                           0.0
# 1        97             53                   5                           1.0
# 2        90             55                   5                           0.0
# 3        55             28                   5                           0.0
# 4        85             42                   4                           1.0
# ...     ...            ...                 ...                           ...
# 6156     12              2                   0                           0.0
# 6157     13              4                   0                           0.0
# 6158     14              1                   0                           0.0
# 6159     17              4                   0                           0.0
# 6160     19              4                   0                           0.0
#
#       Home_Goals  ...  Shots_On_Goal_Rate  Year  Base Salary  Defender  \
# 0             12  ...               59.49  2007     265000.0         0
# 1             13  ...               54.64  2007    1500000.0         0
# 2              7  ...               61.11  2007     325008.0         0
# 3              8  ...               50.91  2007      72500.0         0
# 4              9  ...               49.41  2007     245000.0         0
# ...          ...  ...                 ...   ...          ...       ...
# 6156           0  ...               16.67  2020     549996.0         1
# 6157           0  ...               30.77  2020     307000.0         0
# 6158           0  ...                7.14  2020     320000.0         0
# 6159           0  ...               23.53  2020     310610.0         0
# 6160           0  ...               21.05  2020     725000.0         1
#
#       Forward  Midfielder  Penalty_Kicks_Scored  Penalty_Kicks_Taken  \
# 0           1           0                     0                    0
# 1           1           0                     5                    5
# 2           1           0                     0                    0
# 3           1           0                     0                    0
# 4           1           0                     1                    1
# ...       ...         ...                   ...                  ...
# 6156        0           0                     0                    0
# 6157        0           1                     0                    0
# 6158        0           1                     0                    0
# 6159        0           1                     0                    0
# 6160        0           0                     0                    0
#
#       Salary Cap  Bonus Pay
# 0        2100000    28125.0
# 1        2100000    93750.0
# 2        2100000    25000.0
# 3        2100000        0.0
# 4        2100000     3750.0
# ...          ...        ...
# 6156     4900000    54000.0
# 6157     4900000        0.0
# 6158     4900000     5000.0
# 6159     4900000        0.0
# 6160     4900000        0.0
#
# [5543 rows x 32 columns]

# %%
stats_salaries_df['Penalty_Kicks_Scored'] = stats_salaries_df['Penalty_Kicks_Scored'].astype(int)
stats_salaries_df["Penalty_Kicks_Taken"]= stats_salaries_df['Penalty_Kicks_Taken'].astype(int)

# %%
X = stats_salaries_df.drop(columns='Base Salary')
y = stats_salaries_df['Base Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
sns.set(rc={'figure.figsize': (10, 10)})

sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

dummy_mse = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_squared_error'))
dummy_mse
# Out:
# -384211411668.69543

# %%
dummy_rmse = np.sqrt(-dummy_mse)
dummy_rmse
# Out:
# 619847.893977785

# %%
y_pred = dummy.predict(X_train)

dummy_score = r2_score(y_train, y_pred)
dummy_score
# Out:
# 0.0

# %%
dummy_mae = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_absolute_error'))
dummy_mae
# Out:
# -271259.95152306615

# %%
lr = LinearRegression()
scaler = StandardScaler()
X_train_sc= scaler.fit_transform(X_train)
X_test_sc= scaler.transform(X_test)

lr.fit(X_train_sc, y_train)
y_pred = lr.predict(X_train_sc)

# %%
plt.scatter(y_train, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
lr_mse = np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
lr_mse
# Out:
# -251189360567.46957

# %%
rmse = np.sqrt(-lr_mse)
rmse
# Out:
# 501187.9493438261

# %%
lr_mae =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
lr_mae
# Out:
# -195866.285112689

# %%
y_pred_lr = lr.predict(X_train_sc)

lr_score =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'r2'))
lr_score
# Out:
# 0.24610159257364614

# %%
pipe = Pipeline([
    ('pca', PCA(random_state=42)),
    ('lr', LinearRegression())
])

# %%
param_grid = {
    'pca__n_components': [23, 24, 25],
    'pca__copy': [False, True],
    'pca__whiten': [False, True]
}

# %%
grid = GridSearchCV(pipe, param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
grid.fit(X_train_sc, y_train)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 0.24132258231333678
# {'pca__copy': False, 'pca__n_components': 25, 'pca__whiten': True}

# %%
#stats_salaries_df[['Goals_per_90', 'Assists_per_90', 'Shots_per_90', 'Shots_on_Goal_per_90', 'Game_Winning_Goals_per_90',
#                   'Game_Winning_Assists_per_90', 'Fouls_Committed_per_90', 'Fouls_Suffered_per_90', 'Offsides_per_90',
#                   'Yellow_Cards_per_90', 'Red_Cards_per_90', 'Base_Salary_per_90']] = stats_salaries_df[['Goals', 'Assists', 'Shots',
#                        'Shots_On_Goal', 'Game_Winning_Goals', 'Game_Winning_Assists', 'Fouls_Committed', 'Fouls_Suffered', 
#                        'Offsides','Yellow_Cards', 'Red_Cards', 'Base Salary']].div((stats_salaries_df['Total_Minutes_Played'] / 90), axis=0)

# %%
#stats_salaries_df.fillna(value=0, inplace=True)

# %%
#stats_salaries_df['Games_Played'] = stats_salaries_df['Total_Minutes_Played'] / 90

# %%
#sns.set(rc={'figure.figsize': (10, 10)})

#sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
#salary90_corrs = stats_salaries_df.corr()['Base_Salary_per_90'].map(abs).sort_values(ascending=False)
#salary90_corrs

# %%
#stats_salaries_df.drop(columns=['Fouls_Committed', 'Yellow_Cards', 'Red_Cards', 'Goals_per_90_Minutes', 'Assists_per_90_Minutes',
                        #'Penalty_Kick_Conversion_Rate', 'Shots_Conversion', 'Shots_On_Goal_Rate'], inplace=True)

# %%
rf = RandomForestRegressor(random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_score = np.mean(cross_val_score(rf, X_train, y_train, cv=5))
rf_score
# Out:
# 0.5209219028023732

# %%
rf_mse = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
rf_mse
# Out:
# -178269827688.93634

# %%
rf_rmse = np.sqrt(-rf_mse)
rf_rmse
# Out:
# 422220.117579606

# %%
rf_mae = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
rf_mae
# Out:
# -159519.30175885902

# %%
rfpipe = Pipeline([('pca', PCA(random_state=42)),
                    ('rf', RandomForestRegressor(random_state=42))])

# %%
rf_param_grid = {
    'pca__n_components': [10, 20, 30],
    'rf__n_estimators': [10, 50, 100],
    'rf__min_samples_split': [2, 5, 10],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0.5658673111047489
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 2, 'rf__n_estimators': 50}

# %%
rf_param_grid = {
    'pca__n_components': [30, 50, 70],
    'rf__n_estimators': [75, 125, 175],
    'rf__min_samples_split': [3, 5, 7],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.4s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.2s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.1s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.6s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.5s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.3s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   6.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   6.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.6s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  14.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  14.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  17.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  13.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  14.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  28.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  11.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=  12.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  27.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=  11.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  26.8s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.1s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 270 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=50 must be between 0 and min(n_samples, n_features)=31 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=70 must be between 0 and min(n_samples, n_features)=31 with svd_solver='full'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.55169643 0.5545709  0.55322109 0.54884056 0.55057899 0.54995693
#  0.54453674 0.54665212 0.54898631 0.54954477 0.55155862 0.55178038
#  0.549689   0.55171376 0.5506247  0.54532548 0.54733929 0.54913539
#  0.56656674 0.56897085 0.57322174 0.56535534 0.56829902 0.57223594
#  0.56347501 0.56666447 0.57005156        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the train scores are non-finite: [0.92876119 0.9287264  0.93091221 0.91031969 0.9096096  0.91186037
#  0.89056861 0.89055867 0.89268791 0.92886593 0.92877512 0.93086091
#  0.91031406 0.909684   0.91202275 0.89053124 0.89051129 0.8926781
#  0.93319663 0.93249389 0.93456022 0.91434379 0.91351253 0.91566746
#  0.89373298 0.89246051 0.89433788        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# 0.5732217439491877
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 3, 'rf__n_estimators': 175}

# %%
rf_param_grid = {
    'pca__n_components': [25, 30, 35],
    'rf__n_estimators': [110, 125, 140],
    'rf__min_samples_split': [2, 3, 4],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 135 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=35 must be between 0 and min(n_samples, n_features)=31 with svd_solver='full'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.53388018 0.5349318  0.53665661 0.53183123 0.53223969 0.53339291
#  0.52824987 0.52664385 0.52724787 0.53263305 0.53285231 0.53362511
#  0.53357981 0.53323353 0.53376405 0.52781753 0.52635043 0.52703681
#  0.55454846 0.55628421 0.55787049 0.55694112 0.56031745 0.56027405
#  0.55808715 0.56055175 0.560557   0.54445791 0.54653356 0.54847618
#  0.55500383 0.5545709  0.55459719 0.5496352  0.55078896 0.5522625
#  0.55037691 0.55232672 0.55334302 0.55155552 0.55155862 0.55287674
#  0.55010007 0.55185038 0.55282975 0.56575446 0.56772043 0.56804538
#  0.56773401 0.56897085 0.56973374 0.56869733 0.56912577 0.56950329
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the train scores are non-finite: [0.93283805 0.93362212 0.93495443 0.92465472 0.92544398 0.92666472
#  0.91446414 0.91541824 0.9166977  0.93317127 0.93387581 0.93503991
#  0.92451862 0.92544676 0.92674245 0.91454246 0.91541208 0.9167534
#  0.93601937 0.93664203 0.93783548 0.92953182 0.93019262 0.93135452
#  0.91977165 0.92070808 0.92207008 0.93468073 0.93527683 0.93646494
#  0.92798079 0.9287264  0.93011908 0.91927656 0.91998211 0.92137737
#  0.93473024 0.93541581 0.93673221 0.92811731 0.92877512 0.9301074
#  0.91926264 0.91995851 0.92129212 0.93706378 0.9377614  0.93916277
#  0.93202603 0.93249389 0.93398256 0.92270158 0.92329832 0.92480129
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# 0.569733738420339
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 3, 'rf__n_estimators': 140}

# %%
pca = PCA()
pca.fit(X_train_sc, y_train)
# Out:
# PCA()

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_k = knn.predict(X_train_sc)
y_pred_k
# Out:
# array([119170.   , 256000.784, 334998.4  , ..., 221677.4  ,  70678.2  ,
#        113415.8  ])

# %%
knn_train = knn.score(X_train_sc, y_train)
knn_val = knn.score(X_test_sc, y_test)
print(knn_train)
print(knn_val)
# Out:
# 0.6281896417218495
# 0.3158481965123443

# %%
plt.scatter(y_train, y_pred_k)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
X_test= np.linspace(X_train_sc.min(), X_train_sc.max(), 500)[:, np.newaxis]

# %%
plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
plt.plot(X_train_sc, X_test, color='blue', label='True Values')
plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
plt.xlabel('X')
plt.ylabel('y')
plt.title('KNeighborsRegressor')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
#       2 plt.plot(X_train_sc, X_test, color='blue', label='True Values')
#       3 plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4652, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4650 y = np.ma.ravel(y)
#    4651 if x.size != y.size:
# -> 4652     raise ValueError("x and y must be the same size")
#    4654 if s is None:
#    4655     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4656          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
knn_mse = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5, scoring = 'neg_mean_squared_error'))
knn_mse

# %%
knn_rmse = np.sqrt(-knn_mse)
knn_rmse

# %%
knn_mae = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
knn_mae

# %%
knn_r2 = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'r2'))
knn_r2

# %%
kpipe = Pipeline([('pca', PCA(random_state=42)),
                  ('knn', KNeighborsRegressor())
                 ])

# %%
k_param_grid = {
    'pca__n_components': [5, 10, 15],
    'knn__n_neighbors': [3, 5, 7],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_param_grid = {
    'pca__n_components': [7, 10, 13],
    'knn__n_neighbors': [7, 15, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_param_grid = {
    'pca__n_components': [9, 10, 11],
    'knn__n_neighbors': [7, 9, 11],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=5, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_rmse_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_k = knn.fit(X_train_sc, y_train).predict(X_train_sc)
    k_mse = mean_squared_error(y_train, y_pred_k)
    k_rmse = np.sqrt(k_mse)
    k_rmse_values.append(k_rmse)

# %%
k_rmse_v_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_vk = knn.fit(X_test_sc, y_test).predict(X_test_sc)
    k_vmse = mean_squared_error(y_test, y_pred_vk)
    k_vrmse = np.sqrt(k_vse)
    k_rmse_v_values.append(k_vrmse)

# %%
sns.lineplot(x = k_values, y = k_rmse_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("RMSE")
plt.show()

# %%
sns.lineplot(x = k_values, y = k_rmse_v_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("RMSE")
plt.show()

# %%
knn_score= np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5))
knn_score

# %%
knn_score = knn.score(X_train_sc, y_train)
knn_score

# %%
knn_score_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_k = knn.fit(X_train_sc, y_train).predict(X_train_sc)
    knn_score = knn.score(X_train_sc, y_train)
    knn_score_values.append(knn_score)

# %%
sns.lineplot(x = k_values, y = knn_score_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy")

# %%
eigenvalues= pca.explained_variance_
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, marker= 'o')
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalues')
plt.show()
