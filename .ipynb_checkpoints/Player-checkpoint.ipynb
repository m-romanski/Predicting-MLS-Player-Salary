# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.datasets import make_blobs
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import r2_score, silhouette_score, mean_squared_error, mean_absolute_error 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor

# %%
# create dataframes of csv
player_stats_salaries_df = pd.read_csv('./data/player_stats_salaries.csv')

# %%
#New index was created
player_stats_salaries_df.head()
# Out:
#    Unnamed: 0             Player Club POS  GP  GS  MINS   G   A  SHTS  ...  \
# 0           0  chris wondolowski   SJ   F  32  31  2813  27   7   127  ...
# 1           1       kenny cooper  NY    F  33  26  2505  18   3    84  ...
# 2           2     alvaro saborio  RSL   F  31  26  2390  17   3    87  ...
# 3           3       robbie keane  LA    F  28  28  2519  16   9    94  ...
# 4           4      thierry henry  NY    F  25  24  2108  15  12    88  ...
#
#    FC  FS OFF  YC  RC   SOG%  Year  Season  Base Salary  Base Guaranteed Comp.
# 0  19  25  28   3   0  43.31  2012     reg     300000.0              300000.00
# 1  36  28  20   3   0  54.76  2012     reg     275000.0              292500.00
# 2  35  37  37   5   0  45.98  2012     reg     350000.0              405625.00
# 3  15  34  27   0   0  45.74  2012     reg    2917241.0             3417242.75
# 4  18  26  24   5   0  42.05  2012     reg    5000000.0             5600000.00
#
# [5 rows x 31 columns]

# %%
# remove Unnamed column
player_stats_salaries_df.drop(columns='Unnamed: 0', inplace=True)

# %%
player_stats_salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4517 entries, 0 to 4516
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Player                 4517 non-null   object
#  1   Club                   4517 non-null   object
#  2   POS                    4517 non-null   object
#  3   GP                     4517 non-null   int64
#  4   GS                     4517 non-null   int64
#  5   MINS                   4517 non-null   int64
#  6   G                      4517 non-null   int64
#  7   A                      4517 non-null   int64
#  8   SHTS                   4517 non-null   int64
#  9   SOG                    4517 non-null   int64
#  10  GWG                    4517 non-null   int64
#  11  PKG/A                  4517 non-null   object
#  12  HmG                    4517 non-null   int64
#  13  RdG                    4517 non-null   int64
#  14  G/90min                4517 non-null   float64
#  15  SC%                    4517 non-null   float64
#  16  GWA                    4517 non-null   int64
#  17  HmA                    4517 non-null   int64
#  18  RdA                    4517 non-null   int64
#  19  A/90min                4517 non-null   float64
#  20  FC                     4517 non-null   int64
#  21  FS                     4517 non-null   int64
#  22  OFF                    4517 non-null   int64
#  23  YC                     4517 non-null   int64
#  24  RC                     4517 non-null   int64
#  25  SOG%                   3690 non-null   float64
#  26  Year                   4517 non-null   int64
#  27  Season                 4517 non-null   object
#  28  Base Salary            4517 non-null   float64
#  29  Base Guaranteed Comp.  4517 non-null   float64
# dtypes: float64(6), int64(19), object(5)
# memory usage: 1.0+ MB

# %%
player_stats_salaries_df.rename(columns={'PKG/A': 'Penalty_Kick_Conversion_Rate', 'G/90min': 'Goals_per_90_Minutes', 
                                          'A/90min': 'Assists_per_90_Minutes', 'POS': 'Position', 'GP': 'Games_Played',
                                         'GS': 'Games_Started', 'MINS': 'Total_Minutes_Played', 'G': 'Goals',
                                         'A': 'Assists', 'SHTS': 'Shots', 'SOG': 'Shots_On_Goal', 
                                        'GWG': 'Game_Winning_Goals', 'HmG': 'Home_Goals', 'RdG': 'Road_Goals',
                                        'SC%': 'Shots_Conversion', 'GWA': 'Game_Winning_Assists',
                                        'HmA': 'Home_Assists', 'RdA': 'Road_Assists', 'FC': 'Fouls_Committed',
                                        'FS': 'Fouls_Suffered', 'OFF': 'Offsides', 'YC': 'Yellow_Cards',
                                        'RC': 'Red_Cards', 'SOG%': 'Shots_On_Goal_Rate'}, inplace=True)

# %%
player_stats_salaries_df['Penalty_Kick_Conversion_Rate']
# Out:
# 0       5/7
# 1       3/3
# 2       3/3
# 3       1/2
# 4       0/0
#        ...
# 4512    0/0
# 4513    0/0
# 4514    0/0
# 4515    0/0
# 4516    0/0
# Name: Penalty_Kick_Conversion_Rate, Length: 4517, dtype: object

# %%
player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'] = player_stats_salaries_df["Penalty_Kicks_Scored"].astype(float) / player_stats_salaries_df["Penalty_Kicks_Taken"].astype(float)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].fillna(value=0, inplace=True)

# %%
player_stats_salaries_df['Shots_On_Goal_Rate'].fillna(value=0, inplace=True)

# %%
salary_cap = {2012: 2810000, 2013: 2950000, 2014: 3100000, 2015: 3490000, 2016: 3660000, 2017: 3845000,
              2018: 4035000, 2019: 4240000, 2020: 4900000}
player_stats_salaries_df['Salary Cap'] = player_stats_salaries_df['Year'].apply(lambda year: salary_cap.get(year, 0))

# %%
stats_salaries_df = player_stats_salaries_df.drop(columns=['Player', 'Club', 'Position', 'Season', 'Base Guaranteed Comp.'
                                                           ])

# %%
stats_salaries_df.tail()
# Out:
#       Games_Played  Games_Started  Total_Minutes_Played  Goals  Assists  \
# 4512            15             15                  1318      0        0
# 4513            15              8                   769      0        0
# 4514            21             20                  1701      0        0
# 4515            16             10                   896      0        0
# 4516            20             20                  1712      0        0
#
#       Shots  Shots_On_Goal  Game_Winning_Goals  Penalty_Kick_Conversion_Rate  \
# 4512     12              2                   0                           0.0
# 4513     13              4                   0                           0.0
# 4514     14              1                   0                           0.0
# 4515     17              4                   0                           0.0
# 4516     19              4                   0                           0.0
#
#       Home_Goals  ...  Fouls_Suffered  Offsides  Yellow_Cards  Red_Cards  \
# 4512           0  ...               9         2             0          0
# 4513           0  ...               5         0             2          0
# 4514           0  ...              14         0             4          0
# 4515           0  ...               4         0             3          0
# 4516           0  ...               6         1             5          1
#
#       Shots_On_Goal_Rate  Year  Base Salary  Penalty_Kicks_Scored  \
# 4512               16.67  2020     549996.0                     0
# 4513               30.77  2020     307000.0                     0
# 4514                7.14  2020     320000.0                     0
# 4515               23.53  2020     310610.0                     0
# 4516               21.05  2020     725000.0                     0
#
#       Penalty_Kicks_Taken  Salary Cap
# 4512                    0     4900000
# 4513                    0     4900000
# 4514                    0     4900000
# 4515                    0     4900000
# 4516                    0     4900000
#
# [5 rows x 28 columns]

# %%
stats_salaries_df['Penalty_Kicks_Scored'] = stats_salaries_df['Penalty_Kicks_Scored'].astype(int)
stats_salaries_df["Penalty_Kicks_Taken"]= stats_salaries_df['Penalty_Kicks_Taken'].astype(int)

# %%
X = stats_salaries_df.drop(columns='Base Salary')
y = stats_salaries_df['Base Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
sns.set(rc={'figure.figsize': (10, 10)})

sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

dummy_mse = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_squared_error'))
dummy_mse
# Out:
# -401420848396.9852

# %%
dummy_rmse = np.sqrt(-dummy_mse)
dummy_rmse
# Out:
# 633577.8155814684

# %%
y_pred = dummy.predict(X_train)

dummy_score = r2_score(y_train, y_pred)
dummy_score
# Out:
# 0.0

# %%
dummy_mae = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_absolute_error'))
dummy_mae
# Out:
# -289598.49215019343

# %%
lr = LinearRegression()
scaler = StandardScaler()
X_train_sc= scaler.fit_transform(X_train)
X_test_sc= scaler.transform(X_test)

lr.fit(X_train_sc, y_train)
y_pred = lr.predict(X_train_sc)

# %%
plt.scatter(y_train, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
lr_mse = np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
lr_mse
# Out:
# -314644315713.473

# %%
rmse = np.sqrt(-lr_mse)
rmse
# Out:
# 560931.649769803

# %%
lr_mae =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
lr_mae
# Out:
# -244353.96530029163

# %%
y_pred_lr = lr.predict(X_train_sc)

lr_score =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'r2'))
lr_score
# Out:
# 0.20495790397860772

# %%
pipe = Pipeline([
    ('pca', PCA(random_state=42)),
    ('lr', LinearRegression())
])

# %%
param_grid = {
    'pca__n_components': [23, 24, 25],
    'pca__copy': [False, True],
    'pca__whiten': [False, True]
}

# %%
grid = GridSearchCV(pipe, param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
grid.fit(X_train_sc, y_train)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 0.20504567151038827
# {'pca__copy': False, 'pca__n_components': 25, 'pca__whiten': True}

# %%
#stats_salaries_df[['Goals_per_90', 'Assists_per_90', 'Shots_per_90', 'Shots_on_Goal_per_90', 'Game_Winning_Goals_per_90',
#                   'Game_Winning_Assists_per_90', 'Fouls_Committed_per_90', 'Fouls_Suffered_per_90', 'Offsides_per_90',
#                   'Yellow_Cards_per_90', 'Red_Cards_per_90', 'Base_Salary_per_90']] = stats_salaries_df[['Goals', 'Assists', 'Shots',
#                        'Shots_On_Goal', 'Game_Winning_Goals', 'Game_Winning_Assists', 'Fouls_Committed', 'Fouls_Suffered', 
#                        'Offsides','Yellow_Cards', 'Red_Cards', 'Base Salary']].div((stats_salaries_df['Total_Minutes_Played'] / 90), axis=0)

# %%
#stats_salaries_df.fillna(value=0, inplace=True)

# %%
#stats_salaries_df['Games_Played'] = stats_salaries_df['Total_Minutes_Played'] / 90

# %%
#sns.set(rc={'figure.figsize': (10, 10)})

#sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
#salary90_corrs = stats_salaries_df.corr()['Base_Salary_per_90'].map(abs).sort_values(ascending=False)
#salary90_corrs

# %%
#stats_salaries_df.drop(columns=['Fouls_Committed', 'Yellow_Cards', 'Red_Cards', 'Goals_per_90_Minutes', 'Assists_per_90_Minutes',
                        #'Penalty_Kick_Conversion_Rate', 'Shots_Conversion', 'Shots_On_Goal_Rate'], inplace=True)

# %%
rf = RandomForestRegressor(random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_score = np.mean(cross_val_score(rf, X_train, y_train, cv=5))
rf_score
# Out:
# 0.26328410497455834

# %%
rf_mse = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
rf_mse
# Out:
# -304521526469.91125

# %%
rf_rmse = np.sqrt(-rf_mse)
rf_rmse
# Out:
# 551834.6912526534

# %%
rf_mae = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
rf_mae
# Out:
# -228738.24996647617

# %%
rfpipe = Pipeline([('pca', PCA(random_state=42)),
                    ('rf', RandomForestRegressor(random_state=42))])

# %%
rf_param_grid = {
    'pca__n_components': [10, 20, 30],
    'rf__n_estimators': [10, 50, 100],
    'rf__min_samples_split': [2, 5, 10],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 135 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=30 must be between 0 and min(n_samples, n_features)=27 with svd_solver='full'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.14245372 0.19441303 0.20528869 0.13973302 0.19547946 0.20402604
#  0.13986383 0.18385223 0.19438552 0.15289443 0.20131745 0.20730431
#  0.13670385 0.19420968 0.20483195 0.13947203 0.18384819 0.19457983
#  0.15933129 0.22406327 0.22972997 0.15510017 0.2232683  0.23159717
#  0.18639973 0.2251995  0.23126725 0.0761632  0.1522175  0.16153282
#  0.08259628 0.16297379 0.16729816 0.11347029 0.16318956 0.16624115
#  0.07982866 0.15226966 0.16661929 0.07337888 0.15960336 0.16480791
#  0.11327961 0.16494264 0.16654513 0.11285986 0.20801053 0.21899731
#  0.11878822 0.21035759 0.21589947 0.14801795 0.21301372 0.22131263
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the train scores are non-finite: [0.83996179 0.87226972 0.87874162 0.77923169 0.8050225  0.81098328
#  0.68859212 0.71501331 0.72058145 0.83628456 0.87168233 0.878299
#  0.7788875  0.80501508 0.81093729 0.68857527 0.71482965 0.72050698
#  0.84402773 0.87541002 0.88336603 0.7914986  0.81644526 0.82475461
#  0.70628908 0.72823879 0.73638509 0.83449582 0.8672638  0.87360005
#  0.77627715 0.80277847 0.80637858 0.70581144 0.7222575  0.72582226
#  0.83455066 0.86712005 0.873533   0.77616356 0.80259204 0.80619531
#  0.70689546 0.7224072  0.72580689 0.84011619 0.87164064 0.87894446
#  0.79533382 0.82180043 0.82896826 0.71982617 0.74235298 0.74715585
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# 0.23159717409721323
# {'pca__n_components': 10, 'rf__criterion': 'poisson', 'rf__min_samples_split': 5, 'rf__n_estimators': 100}

# %%
rf_param_grid = {
    'pca__n_components': [15, 20, 25],
    'rf__n_estimators': [75, 125, 175],
    'rf__min_samples_split': [10, 20, 30],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0.22905175699573208
# {'pca__n_components': 15, 'rf__criterion': 'poisson', 'rf__min_samples_split': 10, 'rf__n_estimators': 175}

# %%
rf_param_grid = {
    'pca__n_components': [12, 15, 18],
    'rf__n_estimators': [160, 175, 190],
    'rf__min_samples_split': [8, 9, 10, 11, 12],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 135 candidates, totalling 675 fits
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.3s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.3s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   1.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   1.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.3s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   3.3s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   3.0s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   1.7s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   1.5s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.7s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   7.2s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   6.4s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   6.8s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   7.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   0.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   0.0s
# 0.22958063685835423
# {'pca__n_components': 18, 'rf__criterion': 'poisson', 'rf__min_samples_split': 9, 'rf__n_estimators': 175}

# %%
pca = PCA()
pca.fit(X_train_sc, y_train)
# Out:
# PCA()

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_k = knn.predict(X_train_sc)
y_pred_k
# Out:
# array([224984.4  , 607999.192,  69000.016, ..., 234964.   ,  96675.   ,
#         72599.984])

# %%
knn_train = knn.score(X_train_sc, y_train)
knn_val = knn.score(X_test_sc, y_test)
print(knn_train)
print(knn_val)
# Out:
# 0.39226539419941575
# 0.17391001313493737

# %%
plt.scatter(y_train, y_pred_k)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
X_test= np.linspace(X_train_sc.min(), X_train_sc.max(), 500)[:, np.newaxis]

# %%
plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
plt.plot(X_train_sc, X_test, color='blue', label='True Values')
plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
plt.xlabel('X')
plt.ylabel('y')
plt.title('KNeighborsRegressor')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
#       2 plt.plot(X_train_sc, X_test, color='blue', label='True Values')
#       3 plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4652, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4650 y = np.ma.ravel(y)
#    4651 if x.size != y.size:
# -> 4652     raise ValueError("x and y must be the same size")
#    4654 if s is None:
#    4655     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4656          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
knn_mse = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5, scoring = 'neg_mean_squared_error'))
knn_mse

# %%
knn_rmse = np.sqrt(-knn_mse)
knn_rmse

# %%
knn_mae = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
knn_mae

# %%
knn_r2 = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'r2'))
knn_r2

# %%
kpipe = Pipeline([('pca', PCA(random_state=42)),
                  ('knn', KNeighborsRegressor())
                 ])

# %%
k_param_grid = {
    'pca__n_components': [5, 10, 15],
    'knn__n_neighbors': [3, 5, 7],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_param_grid = {
    'pca__n_components': [15, 20, 25],
    'knn__n_neighbors': [7, 15, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_param_grid = {
    'pca__n_components': [22, 23, 24],
    'knn__n_neighbors': [21, 22, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=5, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_rmse_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_k = knn.fit(X_train_sc, y_train).predict(X_train_sc)
    k_mse = mean_squared_error(y_train, y_pred_k)
    k_rmse = np.sqrt(k_mse)
    k_rmse_values.append(k_rmse)

# %%
sns.lineplot(x = k_values, y = k_mse_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("MSE")

# %%
knn_score= np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5))
knn_score

# %%
knn_score = knn.score(X_train_sc, y_train)
knn_score

# %%
knn_score_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_k = knn.fit(X_train_sc, y_train).predict(X_train_sc)
    knn_score = knn.score(X_train_sc, y_train)
    knn_score_values.append(knn_score)

# %%
sns.lineplot(x = k_values, y = knn_score_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy")

# %%
eigenvalues= pca.explained_variance_
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, marker= 'o')
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalues')
plt.show()
