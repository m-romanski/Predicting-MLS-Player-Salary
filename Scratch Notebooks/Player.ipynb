# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.datasets import make_blobs
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import r2_score, silhouette_score, mean_squared_error, mean_absolute_error 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor

# %%
# create dataframes of csv
player_stats_salaries_df = pd.read_csv('./data/player_stats_salaries.csv')

# %%
#New index was created
player_stats_salaries_df.head()
# Out:
#    Unnamed: 0            Player Club POS  GP  GS  MINS   G  A  SHTS  ...  FC  \
# 0           0    luciano emilio  DC    F  29  28  2410  20  1    79  ...  35
# 1           1  juan pablo angel  NY    F  24  24  2125  19  5    97  ...  31
# 2           2   taylor twellman  NE    F  26  25  2283  16  3    90  ...  13
# 3           4    maykel galindo  CHV   F  28  24  2021  12  5    55  ...  44
# 4           5        ante razov  CHV   F  26  24  2041  11  8    85  ...  37
#
#    FS OFF  YC  RC   SOG%  Year  Season  Base Salary  Base Guaranteed Comp.
# 0  39  21   2   0  59.49  2007     reg     265000.0               293125.0
# 1  20  42   2   1  54.64  2007     reg    1500000.0              1593750.0
# 2  41  21   2   0  61.11  2007     reg     325008.0               350008.0
# 3  53  30   6   0  50.91  2007     reg      72500.0                72500.0
# 4  33  30   2   0  49.41  2007     reg     245000.0               248750.0
#
# [5 rows x 31 columns]

# %%
# remove Unnamed column
player_stats_salaries_df.drop(columns='Unnamed: 0', inplace=True)

# %%
player_stats_salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6161 entries, 0 to 6160
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Player                 6161 non-null   object
#  1   Club                   6161 non-null   object
#  2   POS                    6161 non-null   object
#  3   GP                     6161 non-null   int64
#  4   GS                     6161 non-null   int64
#  5   MINS                   6161 non-null   int64
#  6   G                      6161 non-null   int64
#  7   A                      6161 non-null   int64
#  8   SHTS                   6161 non-null   int64
#  9   SOG                    6161 non-null   int64
#  10  GWG                    6161 non-null   int64
#  11  PKG/A                  6161 non-null   object
#  12  HmG                    6161 non-null   int64
#  13  RdG                    6161 non-null   int64
#  14  G/90min                6161 non-null   float64
#  15  SC%                    6161 non-null   float64
#  16  GWA                    6161 non-null   int64
#  17  HmA                    6161 non-null   int64
#  18  RdA                    6161 non-null   int64
#  19  A/90min                6161 non-null   float64
#  20  FC                     6161 non-null   int64
#  21  FS                     6161 non-null   int64
#  22  OFF                    6161 non-null   int64
#  23  YC                     6161 non-null   int64
#  24  RC                     6161 non-null   int64
#  25  SOG%                   5025 non-null   float64
#  26  Year                   6161 non-null   int64
#  27  Season                 6161 non-null   object
#  28  Base Salary            6161 non-null   float64
#  29  Base Guaranteed Comp.  6161 non-null   float64
# dtypes: float64(6), int64(19), object(5)
# memory usage: 1.4+ MB

# %%
for i in range(len(player_stats_salaries_df)):
    pos = player_stats_salaries_df.at[i, 'POS']
    if pos == 'M-F':
        player_stats_salaries_df.at[i, 'POS'] = 'M'
    elif pos == 'D-M':
        player_stats_salaries_df.at[i, 'POS'] = 'D'
    elif pos == 'F-M':
        player_stats_salaries_df.at[i, 'POS'] = 'F'
    elif pos == 'M-D':
        player_stats_salaries_df.at[i, 'POS'] = 'M'

# %%
one_hot = pd.get_dummies(player_stats_salaries_df['POS'])
one_hot
# Out:
#           D      F      M
# 0     False   True  False
# 1     False   True  False
# 2     False   True  False
# 3     False   True  False
# 4     False   True  False
# ...     ...    ...    ...
# 6156   True  False  False
# 6157  False  False   True
# 6158  False  False   True
# 6159  False  False   True
# 6160   True  False  False
#
# [6161 rows x 3 columns]

# %%
one_hot['D'] = one_hot['D'].astype(int)
one_hot['F'] = one_hot['F'].astype(int)
one_hot['M'] = one_hot['M'].astype(int)
one_hot
# Out:
#       D  F  M
# 0     0  1  0
# 1     0  1  0
# 2     0  1  0
# 3     0  1  0
# 4     0  1  0
# ...  .. .. ..
# 6156  1  0  0
# 6157  0  0  1
# 6158  0  0  1
# 6159  0  0  1
# 6160  1  0  0
#
# [6161 rows x 3 columns]

# %%
player_stats_salaries_df['Defender'] = one_hot['D']
player_stats_salaries_df['Forward'] = one_hot['F']
player_stats_salaries_df['Midfielder'] = one_hot['M']
player_stats_salaries_df.drop(columns='POS', inplace=True)

# %%
player_stats_salaries_df
# Out:
#                 Player Club  GP  GS  MINS   G  A  SHTS  SOG  GWG  ... YC  RC  \
# 0       luciano emilio  DC   29  28  2410  20  1    79   47    4  ...  2   0
# 1     juan pablo angel  NY   24  24  2125  19  5    97   53    5  ...  2   1
# 2      taylor twellman  NE   26  25  2283  16  3    90   55    5  ...  2   0
# 3       maykel galindo  CHV  28  24  2021  12  5    55   28    5  ...  6   0
# 4           ante razov  CHV  26  24  2041  11  8    85   42    4  ...  2   0
# ...                ...  ...  ..  ..   ...  .. ..   ...  ...  ...  ... ..  ..
# 6156      nedum onuoha  RSL  15  15  1318   0  0    12    2    0  ...  0   0
# 6157    sacha kljestan   LA  15   8   769   0  0    13    4    0  ...  2   0
# 6158            judson   SJ  21  20  1701   0  0    14    1    0  ...  4   0
# 6159        kelyn rowe   NE  16  10   896   0  0    17    4    0  ...  3   0
# 6160     maxime chanot  NYC  20  20  1712   0  0    19    4    0  ...  5   1
#
#        SOG%  Year  Season  Base Salary  Base Guaranteed Comp.  Defender  \
# 0     59.49  2007     reg     265000.0               293125.0         0
# 1     54.64  2007     reg    1500000.0              1593750.0         0
# 2     61.11  2007     reg     325008.0               350008.0         0
# 3     50.91  2007     reg      72500.0                72500.0         0
# 4     49.41  2007     reg     245000.0               248750.0         0
# ...     ...   ...     ...          ...                    ...       ...
# 6156  16.67  2020     reg     549996.0               603996.0         1
# 6157  30.77  2020     reg     307000.0               307000.0         0
# 6158   7.14  2020     reg     320000.0               325000.0         0
# 6159  23.53  2020     reg     310610.0               310610.0         0
# 6160  21.05  2020     reg     725000.0               725000.0         1
#
#       Forward  Midfielder
# 0           1           0
# 1           1           0
# 2           1           0
# 3           1           0
# 4           1           0
# ...       ...         ...
# 6156        0           0
# 6157        0           1
# 6158        0           1
# 6159        0           1
# 6160        0           0
#
# [6161 rows x 32 columns]

# %%
minimum_salary = {2007: 30000, 2008: 33000, 2009: 34000, 2010: 40000, 2011: 42000, 2012: 45000, 2013: 46500,
                  2014: 48500, 2015: 60000, 2016: 62500, 2017: 65000, 2018: 67500, 2019: 70250, 2020: 81375}

player_stats_salaries_df['Minimum_Salary'] = player_stats_salaries_df['Year'].apply(lambda year: minimum_salary.get(year, 0))

# %%
player_stats_salaries_df[player_stats_salaries_df['Base Salary'] < player_stats_salaries_df['Minimum_Salary']]
# Out:
#                    Player Club  GP  GS  MINS  G  A  SHTS  SOG  GWG  ... RC  \
# 33          adam cristman  NE   28  14  1421  4  4    40   16    0  ...  0
# 71            colin clark  COL  16  16  1321  2  2    26    5    0  ...  0
# 76             kyle brown  RSL   8   3   286  2  0     7    4    1  ...  0
# 106           jeff curtin  CHI   3   3   248  1  0     2    1    0  ...  1
# 109          floyd franks  CHI   7   2   223  1  0     3    1    0  ...  0
# ...                   ...  ...  ..  ..   ... .. ..   ...  ...  ...  ... ..
# 6106     tah brian anunga  NSH  14   8   779  0  0     3    0    0  ...  0
# 6108         kamal miller  ORL  12   9   805  0  0     3    0    0  ...  0
# 6118            alan winn  NSH   7   1   239  0  0     4    1    0  ...  0
# 6119        laurence wyke  ATL   7   2   226  0  0     4    1    0  ...  0
# 6131  sebastian berhalter  CLB   9   4   395  0  0     6    0    0  ...  0
#
#        SOG%  Year  Season  Base Salary  Base Guaranteed Comp.  Defender  \
# 33    40.00  2007     reg      17700.0                17700.0         0
# 71    19.23  2007     reg      17700.0                17700.0         0
# 76    57.14  2007     reg      17700.0                17700.0         0
# 106   50.00  2007     reg      12900.0                12900.0         1
# 109   33.33  2007     reg      17700.0                17700.0         0
# ...     ...   ...     ...          ...                    ...       ...
# 6106   0.00  2020     reg      63547.0                63547.0         0
# 6108   0.00  2020     reg      63547.0                63547.0         1
# 6118  25.00  2020     reg      63547.0                63547.0         0
# 6119  25.00  2020     reg      63547.0                63547.0         1
# 6131   0.00  2020     reg      75000.0                76250.0         0
#
#       Forward  Midfielder  Minimum_Salary
# 33          1           0           30000
# 71          0           1           30000
# 76          1           0           30000
# 106         0           0           30000
# 109         0           1           30000
# ...       ...         ...             ...
# 6106        0           1           81375
# 6108        0           0           81375
# 6118        1           0           81375
# 6119        0           0           81375
# 6131        0           1           81375
#
# [794 rows x 33 columns]

# %%
for i, salary in player_stats_salaries_df.iterrows():
    if player_stats_salaries_df.at[i, 'Base Salary'] < player_stats_salaries_df.at[i, 'Minimum_Salary']:
        player_stats_salaries_df.drop(i, inplace=True)

# %%
player_stats_salaries_df
# Out:
#                 Player Club  GP  GS  MINS   G  A  SHTS  SOG  GWG  ... RC  \
# 0       luciano emilio  DC   29  28  2410  20  1    79   47    4  ...  0
# 1     juan pablo angel  NY   24  24  2125  19  5    97   53    5  ...  1
# 2      taylor twellman  NE   26  25  2283  16  3    90   55    5  ...  0
# 3       maykel galindo  CHV  28  24  2021  12  5    55   28    5  ...  0
# 4           ante razov  CHV  26  24  2041  11  8    85   42    4  ...  0
# ...                ...  ...  ..  ..   ...  .. ..   ...  ...  ...  ... ..
# 6156      nedum onuoha  RSL  15  15  1318   0  0    12    2    0  ...  0
# 6157    sacha kljestan   LA  15   8   769   0  0    13    4    0  ...  0
# 6158            judson   SJ  21  20  1701   0  0    14    1    0  ...  0
# 6159        kelyn rowe   NE  16  10   896   0  0    17    4    0  ...  0
# 6160     maxime chanot  NYC  20  20  1712   0  0    19    4    0  ...  1
#
#        SOG%  Year  Season  Base Salary  Base Guaranteed Comp.  Defender  \
# 0     59.49  2007     reg     265000.0               293125.0         0
# 1     54.64  2007     reg    1500000.0              1593750.0         0
# 2     61.11  2007     reg     325008.0               350008.0         0
# 3     50.91  2007     reg      72500.0                72500.0         0
# 4     49.41  2007     reg     245000.0               248750.0         0
# ...     ...   ...     ...          ...                    ...       ...
# 6156  16.67  2020     reg     549996.0               603996.0         1
# 6157  30.77  2020     reg     307000.0               307000.0         0
# 6158   7.14  2020     reg     320000.0               325000.0         0
# 6159  23.53  2020     reg     310610.0               310610.0         0
# 6160  21.05  2020     reg     725000.0               725000.0         1
#
#       Forward  Midfielder  Minimum_Salary
# 0           1           0           30000
# 1           1           0           30000
# 2           1           0           30000
# 3           1           0           30000
# 4           1           0           30000
# ...       ...         ...             ...
# 6156        0           0           81375
# 6157        0           1           81375
# 6158        0           1           81375
# 6159        0           1           81375
# 6160        0           0           81375
#
# [5367 rows x 33 columns]

# %%
player_stats_salaries_df.rename(columns={'PKG/A': 'Penalty_Kick_Conversion_Rate', 'G/90min': 'Goals_per_90_Minutes', 
                                          'A/90min': 'Assists_per_90_Minutes', 'GP': 'Games_Played',
                                         'GS': 'Games_Started', 'MINS': 'Total_Minutes_Played', 'G': 'Goals',
                                         'A': 'Assists', 'SHTS': 'Shots', 'SOG': 'Shots_On_Goal', 
                                        'GWG': 'Game_Winning_Goals', 'HmG': 'Home_Goals', 'RdG': 'Road_Goals',
                                        'SC%': 'Shots_Conversion', 'GWA': 'Game_Winning_Assists',
                                        'HmA': 'Home_Assists', 'RdA': 'Road_Assists', 'FC': 'Fouls_Committed',
                                        'FS': 'Fouls_Suffered', 'OFF': 'Offsides', 'YC': 'Yellow_Cards',
                                        'RC': 'Red_Cards', 'SOG%': 'Shots_On_Goal_Rate'}, inplace=True)

# %%
player_stats_salaries_df['Penalty_Kick_Conversion_Rate']
# Out:
# 0       0/0
# 1       5/5
# 2       0/0
# 3       0/0
# 4       1/1
#        ...
# 6156    0/0
# 6157    0/0
# 6158    0/0
# 6159    0/0
# 6160    0/0
# Name: Penalty_Kick_Conversion_Rate, Length: 5367, dtype: object

# %%
player_stats_salaries_df = player_stats_salaries_df[player_stats_salaries_df['Total_Minutes_Played'] != 0]

# %%
player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'] = player_stats_salaries_df["Penalty_Kicks_Scored"].astype(float) / player_stats_salaries_df["Penalty_Kicks_Taken"].astype(float)
player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].fillna(value=0, inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/132888053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/132888053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df[["Penalty_Kicks_Scored", "Penalty_Kicks_Taken"]] = player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].str.split("/", expand=True)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/132888053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Penalty_Kick_Conversion_Rate'] = player_stats_salaries_df["Penalty_Kicks_Scored"].astype(float) / player_stats_salaries_df["Penalty_Kicks_Taken"].astype(float)
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/132888053.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Penalty_Kick_Conversion_Rate'].fillna(value=0, inplace=True)

# %%
player_stats_salaries_df['Shots_On_Goal_Rate'].fillna(value=0, inplace=True)
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/825700931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Shots_On_Goal_Rate'].fillna(value=0, inplace=True)

# %%
salary_cap = {2007: 2100000, 2008: 2300000, 2009: 2300000, 2010: 2550000, 2011: 2670000, 2012: 2810000, 2013: 2950000, 2014: 3100000, 2015: 3490000, 2016: 3660000, 2017: 3845000,
              2018: 4035000, 2019: 4240000, 2020: 4900000}
player_stats_salaries_df['Salary Cap'] = player_stats_salaries_df['Year'].apply(lambda year: salary_cap.get(year, 0))
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/1585667694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Salary Cap'] = player_stats_salaries_df['Year'].apply(lambda year: salary_cap.get(year, 0))

# %%
player_stats_salaries_df['Bonus Pay'] = player_stats_salaries_df['Base Guaranteed Comp.'] - player_stats_salaries_df['Base Salary']
# Out:
# /var/folders/g_/5gwjpx2j5c7cg2mn_rrdzqpc0000gn/T/ipykernel_50658/1575893766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_stats_salaries_df['Bonus Pay'] = player_stats_salaries_df['Base Guaranteed Comp.'] - player_stats_salaries_df['Base Salary']

# %%
stats_salaries_df = player_stats_salaries_df.drop(columns=['Player', 'Club', 'Season', 'Base Guaranteed Comp.'
                                                           ])

# %%
stats_salaries_df
# Out:
#       Games_Played  Games_Started  Total_Minutes_Played  Goals  Assists  \
# 0               29             28                  2410     20        1
# 1               24             24                  2125     19        5
# 2               26             25                  2283     16        3
# 3               28             24                  2021     12        5
# 4               26             24                  2041     11        8
# ...            ...            ...                   ...    ...      ...
# 6156            15             15                  1318      0        0
# 6157            15              8                   769      0        0
# 6158            21             20                  1701      0        0
# 6159            16             10                   896      0        0
# 6160            20             20                  1712      0        0
#
#       Shots  Shots_On_Goal  Game_Winning_Goals  Penalty_Kick_Conversion_Rate  \
# 0        79             47                   4                           0.0
# 1        97             53                   5                           1.0
# 2        90             55                   5                           0.0
# 3        55             28                   5                           0.0
# 4        85             42                   4                           1.0
# ...     ...            ...                 ...                           ...
# 6156     12              2                   0                           0.0
# 6157     13              4                   0                           0.0
# 6158     14              1                   0                           0.0
# 6159     17              4                   0                           0.0
# 6160     19              4                   0                           0.0
#
#       Home_Goals  ...  Year  Base Salary  Defender  Forward  Midfielder  \
# 0             12  ...  2007     265000.0         0        1           0
# 1             13  ...  2007    1500000.0         0        1           0
# 2              7  ...  2007     325008.0         0        1           0
# 3              8  ...  2007      72500.0         0        1           0
# 4              9  ...  2007     245000.0         0        1           0
# ...          ...  ...   ...          ...       ...      ...         ...
# 6156           0  ...  2020     549996.0         1        0           0
# 6157           0  ...  2020     307000.0         0        0           1
# 6158           0  ...  2020     320000.0         0        0           1
# 6159           0  ...  2020     310610.0         0        0           1
# 6160           0  ...  2020     725000.0         1        0           0
#
#       Minimum_Salary  Penalty_Kicks_Scored  Penalty_Kicks_Taken  Salary Cap  \
# 0              30000                     0                    0     2100000
# 1              30000                     5                    5     2100000
# 2              30000                     0                    0     2100000
# 3              30000                     0                    0     2100000
# 4              30000                     1                    1     2100000
# ...              ...                   ...                  ...         ...
# 6156           81375                     0                    0     4900000
# 6157           81375                     0                    0     4900000
# 6158           81375                     0                    0     4900000
# 6159           81375                     0                    0     4900000
# 6160           81375                     0                    0     4900000
#
#       Bonus Pay
# 0       28125.0
# 1       93750.0
# 2       25000.0
# 3           0.0
# 4        3750.0
# ...         ...
# 6156    54000.0
# 6157        0.0
# 6158     5000.0
# 6159        0.0
# 6160        0.0
#
# [5025 rows x 33 columns]

# %%
stats_salaries_df['Penalty_Kicks_Scored'] = stats_salaries_df['Penalty_Kicks_Scored'].astype(int)
stats_salaries_df["Penalty_Kicks_Taken"]= stats_salaries_df['Penalty_Kicks_Taken'].astype(int)

# %%
X = stats_salaries_df.drop(columns='Base Salary')
y = stats_salaries_df['Base Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
sns.set(rc={'figure.figsize': (10, 10)})

sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

dummy_mse = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_squared_error'))
dummy_mse
# Out:
# -402280238977.02185

# %%
dummy_rmse = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_root_mean_squared_error'))
dummy_rmse
# Out:
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.6s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.6s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.6s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  20.4s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  21.4s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  19.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  22.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  22.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  21.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  22.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  18.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  22.8s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.1s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.2s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  20.7s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.8s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  20.7s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.8s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.1s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.6s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   3.0s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.6s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.8s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.6s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.6s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  15.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  15.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  16.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  11.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  11.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  25.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=  17.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  17.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  16.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=  14.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  18.8s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.6s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  18.6s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.0s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.8s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.1s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  19.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  18.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  18.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  20.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  18.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  20.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.1s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.5s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.7s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.7s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  22.1s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.2s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  25.1s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.9s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.4s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.7s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   3.0s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.4s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.2s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.7s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  14.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  16.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  20.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  25.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=  26.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=  17.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=  17.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  22.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  18.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  20.8s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.8s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  16.9s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  19.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  19.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  18.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  20.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  18.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  18.4s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  22.6s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  22.2s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  22.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.8s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.9s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  25.3s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.4s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.0s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=False, pca__n_components=25, pca__whiten=True; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=23, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.0s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.2s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.9s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.6s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.4s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.9s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.6s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  16.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=  12.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  11.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=  17.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  24.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.6s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=70, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.9s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=145; total time=  17.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  17.5s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.6s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  18.2s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.9s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  23.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  22.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.4s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.1s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.0s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  22.6s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.6s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  21.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  23.8s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.8s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  23.6s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  25.0s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  19.3s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=False; total time=   0.0s
# ...
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  18.1s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  23.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  22.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  18.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  17.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.1s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  20.3s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.4s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  21.6s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.1s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.6s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  21.4s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.4s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.6s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  16.1s
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   2.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=   4.9s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.9s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.6s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.4s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.5s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=100; total time=  15.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=100; total time=  16.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  15.6s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   7.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=  11.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=  18.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=  17.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=  18.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=  17.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=  24.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=175; total time=  24.1s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  20.4s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.2s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=145; total time=  18.7s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  18.4s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  21.5s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.5s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  17.1s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  22.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  23.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  19.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  23.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.7s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=160; total time=  23.0s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.5s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.8s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.2s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=145; total time=  19.8s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.9s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  20.0s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  15.3s
# [CV] END pca__copy=False, pca__n_components=23, pca__whiten=True; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__copy=True, pca__n_components=25, pca__whiten=False; total time=   0.0s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=   5.3s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=   5.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=50; total time=   3.0s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=100; total time=   5.7s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.2s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.3s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  10.1s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  11.5s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   9.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   8.2s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   7.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   8.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=100; total time=  16.1s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=  16.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.4s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=  27.3s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=  10.0s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=  24.2s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  23.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  24.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=125; total time=  15.3s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  18.0s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.7s
# [CV] END pca__n_components=25, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=160; total time=  19.7s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  19.3s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  19.2s
# [CV] END pca__n_components=25, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  20.8s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=175; total time=  21.3s
# [CV] END pca__n_components=25, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  15.9s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=145; total time=  19.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=4, rf__n_estimators=160; total time=  21.7s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=160; total time=  21.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=160; total time=  20.2s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=4, rf__n_estimators=160; total time=  20.9s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=160; total time=  20.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  21.8s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=4, rf__n_estimators=175; total time=  24.6s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  22.4s
# [CV] END pca__n_components=32, rf__criterion=squared_error, rf__min_samples_split=6, rf__n_estimators=175; total time=  23.7s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=145; total time=  19.0s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=145; total time=  18.5s
# [CV] END pca__n_components=32, rf__criterion=friedman_mse, rf__min_samples_split=6, rf__n_estimators=175; total time=  24.8s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=145; total time=  20.1s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=145; total time=  18.6s
# [CV] END pca__n_components=32, rf__criterion=poisson, rf__min_samples_split=6, rf__n_estimators=175; total time=  14.5s

# %%
y_pred = dummy.predict(X_train)

dummy_score = r2_score(y_train, y_pred)
dummy_score
# Out:
# 0.0

# %%
dummy_mae = np.mean(cross_val_score(dummy, X_train, y_train, cv=kf, scoring='neg_mean_absolute_error'))
dummy_mae
# Out:
# -286589.1683311273

# %%
lr = LinearRegression()
scaler = StandardScaler()
X_train_sc= scaler.fit_transform(X_train)
X_test_sc= scaler.transform(X_test)

lr.fit(X_train_sc, y_train)
y_pred = lr.predict(X_train_sc)

# %%
plt.scatter(y_train, y_pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
lr_mse = np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
lr_mse
# Out:
# -307701612297.32306

# %%
# Out:
# 554708.5832194443

# %%
rmse = np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_root_mean_squared_error'))
rmse
# Out:
# -538881.085320706

# %%
lr_mae =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
lr_mae
# Out:
# -218685.19537609155

# %%
y_pred_lr = lr.predict(X_train_sc)

lr_score =  np.mean(cross_val_score(lr, X_train_sc, y_train, cv=kf, scoring = 'r2'))
lr_score
# Out:
# 0.25563544084429435

# %%
pipe = Pipeline([
    ('pca', PCA(random_state=42)),
    ('lr', LinearRegression())
])

# %%
param_grid = {
    'pca__n_components': [23, 24, 25],
    'pca__copy': [False, True],
    'pca__whiten': [False, True]
}

# %%
grid = GridSearchCV(pipe, param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
grid.fit(X_train_sc, y_train)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# 0.25297742860066
# {'pca__copy': False, 'pca__n_components': 25, 'pca__whiten': True}

# %%
#stats_salaries_df[['Goals_per_90', 'Assists_per_90', 'Shots_per_90', 'Shots_on_Goal_per_90', 'Game_Winning_Goals_per_90',
#                   'Game_Winning_Assists_per_90', 'Fouls_Committed_per_90', 'Fouls_Suffered_per_90', 'Offsides_per_90',
#                   'Yellow_Cards_per_90', 'Red_Cards_per_90', 'Base_Salary_per_90']] = stats_salaries_df[['Goals', 'Assists', 'Shots',
#                        'Shots_On_Goal', 'Game_Winning_Goals', 'Game_Winning_Assists', 'Fouls_Committed', 'Fouls_Suffered', 
#                        'Offsides','Yellow_Cards', 'Red_Cards', 'Base Salary']].div((stats_salaries_df['Total_Minutes_Played'] / 90), axis=0)

# %%
#stats_salaries_df.fillna(value=0, inplace=True)

# %%
#stats_salaries_df['Games_Played'] = stats_salaries_df['Total_Minutes_Played'] / 90

# %%
#sns.set(rc={'figure.figsize': (10, 10)})

#sns.heatmap(stats_salaries_df.corr(), annot=True);

# %%
#salary90_corrs = stats_salaries_df.corr()['Base_Salary_per_90'].map(abs).sort_values(ascending=False)
#salary90_corrs

# %%
#stats_salaries_df.drop(columns=['Fouls_Committed', 'Yellow_Cards', 'Red_Cards', 'Goals_per_90_Minutes', 'Assists_per_90_Minutes',
                        #'Penalty_Kick_Conversion_Rate', 'Shots_Conversion', 'Shots_On_Goal_Rate'], inplace=True)

# %%
rf = RandomForestRegressor(random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_score = np.mean(cross_val_score(rf, X_train, y_train, cv=5))
rf_score
# Out:
# 0.5031766165522074

# %%
rf_mse = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_squared_error'))
rf_mse
# Out:
# -190464896897.59424

# %%
rf_rmse = np.sqrt(-rf_mse)
rf_rmse
# Out:
# 436422.8418604991

# %%
rf_mae = np.mean(cross_val_score(rf, X_train, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
rf_mae
# Out:
# -172617.91072398497

# %%
rfpipe = Pipeline([('pca', PCA(random_state=42)),
                    ('rf', RandomForestRegressor(random_state=42))])

# %%
rf_param_grid = {
    'pca__n_components': [10, 20, 30],
    'rf__n_estimators': [10, 50, 100],
    'rf__min_samples_split': [2, 5, 10],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0.5356731286834426
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 5, 'rf__n_estimators': 100}

# %%
rf_param_grid = {
    'pca__n_components': [30, 50, 70],
    'rf__n_estimators': [75, 125, 175],
    'rf__min_samples_split': [3, 5, 7],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END pca__copy=False, pca__n_components=24, pca__whiten=False; total time=   0.1s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.4s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   0.4s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.5s
# [CV] END pca__n_components=10, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.2s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   3.0s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   2.4s
# [CV] END pca__n_components=10, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=50; total time=   2.3s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=10; total time=   0.5s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=2, rf__n_estimators=100; total time=   6.4s
# [CV] END pca__n_components=10, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=100; total time=   4.7s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.3s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.1s
# [CV] END pca__n_components=20, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=50; total time=   5.1s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=2, rf__n_estimators=50; total time=   5.6s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.0s
# [CV] END pca__n_components=20, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  10.4s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   5.5s
# [CV] END pca__n_components=20, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   4.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=2, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.5s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=10, rf__n_estimators=100; total time=  15.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.8s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=10; total time=   1.6s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=10, rf__n_estimators=100; total time=  15.0s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=5, rf__n_estimators=50; total time=   7.5s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=10, rf__n_estimators=50; total time=   6.8s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=  20.7s
# [CV] END pca__n_components=30, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=  26.0s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=  11.3s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=  10.9s
# [CV] END pca__n_components=30, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=  25.7s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=75; total time=  10.4s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=3, rf__n_estimators=175; total time=  25.3s
# [CV] END pca__n_components=30, rf__criterion=poisson, rf__min_samples_split=7, rf__n_estimators=75; total time=   9.9s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=squared_error, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=3, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=5, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=75; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=125; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# [CV] END pca__n_components=50, rf__criterion=friedman_mse, rf__min_samples_split=7, rf__n_estimators=175; total time=   0.0s
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 270 fits failed out of a total of 405.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=50 must be between 0 and min(n_samples, n_features)=32 with svd_solver='full'
#
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 370, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/joblib/memory.py", line 353, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/pipeline.py", line 950, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 460, in fit_transform
#     U, S, Vt = self._fit(X)
#                ^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 510, in _fit
#     return self._fit_full(X, n_components)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/decomposition/_pca.py", line 524, in _fit_full
#     raise ValueError(
# ValueError: n_components=70 must be between 0 and min(n_samples, n_features)=32 with svd_solver='full'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.51184142 0.50783393 0.51075664 0.51374437 0.51193651 0.51351205
#  0.51797743 0.51604993 0.51772415 0.51051466 0.50856944 0.51057418
#  0.51387607 0.51193054 0.51387048 0.51812395 0.5164467  0.51789585
#  0.53311715 0.53087425 0.53550695 0.53417752 0.53118435 0.53671066
#  0.53355658 0.53040378 0.53677973        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# /Users/michaelromanski/anaconda3/envs/streamlit/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the train scores are non-finite: [0.92644569 0.92910419 0.92955404 0.90749772 0.90994821 0.91083331
#  0.88885965 0.89058288 0.89129825 0.92664817 0.92914863 0.92964736
#  0.90762693 0.91006985 0.91093035 0.88884221 0.89061289 0.89132073
#  0.92933272 0.93075019 0.93105006 0.91194775 0.9129078  0.91297157
#  0.89123421 0.89235282 0.89235818        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan]
#   warnings.warn(
# 0.5367797276507584
# {'pca__n_components': 30, 'rf__criterion': 'poisson', 'rf__min_samples_split': 7, 'rf__n_estimators': 175}

# %%
rf_param_grid = {
    'pca__n_components': [25, 30, 32],
    'rf__n_estimators': [145, 160, 175],
    'rf__min_samples_split': [4, 5, 6],
    'rf__criterion': ['squared_error', 'friedman_mse', 'poisson']
}

# %%
rf_grid = GridSearchCV(rfpipe, rf_param_grid, cv=5, verbose=2, n_jobs=-1, return_train_score=True)
rf_grid.fit(X_train, y_train)
print(rf_grid.best_score_)
print(rf_grid.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0.53802096934218
# {'pca__n_components': 32, 'rf__criterion': 'poisson', 'rf__min_samples_split': 5, 'rf__n_estimators': 175}

# %%
pca = PCA()
pca.fit(X_train_sc, y_train)
# Out:
# PCA()

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_k = knn.predict(X_train_sc)
y_pred_k
# Out:
# array([610051.624, 182148.408, 318800.808, ..., 130000.   , 182790.   ,
#         95519.392])

# %%
knn_train = knn.score(X_train_sc, y_train)
knn_val = knn.score(X_test_sc, y_test)
print(knn_train)
print(knn_val)
# Out:
# 0.5934023630915399
# 0.22314731880522687

# %%
plt.scatter(y_train, y_pred_k)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
X_test= np.linspace(X_train_sc.min(), X_train_sc.max(), 500)[:, np.newaxis]

# %%
plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
plt.plot(X_train_sc, X_test, color='blue', label='True Values')
plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
plt.xlabel('X')
plt.ylabel('y')
plt.title('KNeighborsRegressor')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 plt.scatter(X_train_sc, y_train, color='red', label='Training Data')
#       2 plt.plot(X_train_sc, X_test, color='blue', label='True Values')
#       3 plt.plot(X_train_sc, y_pred_k, color='green', label='Predicted Values')
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4652, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4650 y = np.ma.ravel(y)
#    4651 if x.size != y.size:
# -> 4652     raise ValueError("x and y must be the same size")
#    4654 if s is None:
#    4655     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4656          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
knn_mse = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5, scoring = 'neg_mean_squared_error'))
knn_mse

# %%
knn_rmse = np.sqrt(-knn_mse)
knn_rmse

# %%
knn_mae = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'neg_mean_absolute_error'))
knn_mae

# %%
knn_r2 = np.mean(cross_val_score(knn, X_train_sc, y_train, cv=kf, scoring = 'r2'))
knn_r2

# %%
kpipe = Pipeline([('pca', PCA(random_state=42)),
                  ('knn', KNeighborsRegressor())
                 ])

# %%
k_param_grid = {
    'pca__n_components': [5, 10, 15],
    'knn__n_neighbors': [3, 5, 7],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_param_grid = {
    'pca__n_components': [7, 10, 13],
    'knn__n_neighbors': [7, 15, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=kf, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_param_grid = {
    'pca__n_components': [3, 5, 7],
    'knn__n_neighbors': [17, 20, 23],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['minkowski', 'euclidean', 'manhattan']
}

# %%
k_grid = GridSearchCV(kpipe, k_param_grid, n_jobs=-1, cv=5, verbose=2, return_train_score=True)
k_grid.fit(X_train_sc, y_train)
print(k_grid.best_score_)
print(k_grid.best_params_)

# %%
k_rmse_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_k = knn.fit(X_train_sc, y_train).predict(X_train_sc)
    k_mse = mean_squared_error(y_train, y_pred_k)
    k_rmse = np.sqrt(k_mse)
    k_rmse_values.append(k_rmse)

# %%
k_rmse_v_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_vk = knn.fit(X_test_sc, y_test).predict(X_test_sc)
    k_vmse = mean_squared_error(y_test, y_pred_vk)
    k_vrmse = np.sqrt(k_vse)
    k_rmse_v_values.append(k_vrmse)

# %%
sns.lineplot(x = k_values, y = k_rmse_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("RMSE")
plt.show()

# %%
sns.lineplot(x = k_values, y = k_rmse_v_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("RMSE")
plt.show()

# %%
knn_score= np.mean(cross_val_score(knn, X_train_sc, y_train, cv=5))
knn_score

# %%
knn_score = knn.score(X_train_sc, y_train)
knn_score

# %%
knn_score_values = []
k_values = range(1, 10)
for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    y_pred_k = knn.fit(X_train_sc, y_train).predict(X_train_sc)
    knn_score = knn.score(X_train_sc, y_train)
    knn_score_values.append(knn_score)

# %%
sns.lineplot(x = k_values, y = knn_score_values, marker = 'o')
plt.xlabel("K Values")
plt.ylabel("Accuracy")
